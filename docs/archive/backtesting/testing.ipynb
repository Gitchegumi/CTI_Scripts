# %%
import pandas as pd
import numpy as np
from decimal import Decimal
import glob
import backtrader as bt
import matplotlib
import matplotlib.pyplot as plt
import pandas_ta as ta
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

# Ensure plots are rendered inline in the notebook
pio.renderers.default = "notebook"
matplotlib.use('Agg')
# %matplotlib inline

# %%
symbol = "USDJPY"
year = 2011
end_year = 2011
decimals = 2
multiplier = 100
starting_balance = 2500
profit_target = 0.1
max_loss = 0.06
absolute_profit_target = starting_balance * (1 + profit_target)
absolute_max_loss = starting_balance * ( 1 - max_loss)

# %%
# Define the path to your CSV files
file_path_pattern = f'/root/github/CTI_Scripts/py_scripts/backtesting/historical_data/{symbol}/DAT_MT_{symbol}_M1_*.csv'

# Define the column names
column_names = ['DATE', 'TIME', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'TICKVOL', 'VOL', 'SPREAD']

# Load and combine all CSV files
all_files = glob.glob(file_path_pattern)
data_list = []

for file in all_files:
    print(f"Loading file: {file}")  # Debugging: Print file being loaded
    df = pd.read_csv(file, delimiter=',', names=column_names, header=None, dtype=str)
    # print(df.head())  # Debugging: Print the first few rows of the loaded DataFrame
    data_list.append(df)

combined_data = pd.concat(data_list)

# Combine <DATE> and <TIME> into a single datetime column
combined_data['datetime'] = pd.to_datetime(
    combined_data['DATE'] + ' ' + combined_data['TIME'], format='%Y.%m.%d %H:%M', errors='coerce'
)

# Drop rows with NaT in datetime column
combined_data.dropna(subset=['datetime'], inplace=True)

# Set datetime as the index
combined_data.set_index('datetime', inplace=True)
combined_data.sort_index(inplace=True)

# Convert numeric columns to appropriate data types
numeric_columns = ['OPEN', 'HIGH', 'LOW', 'CLOSE', 'TICKVOL', 'VOL', 'SPREAD']
combined_data[numeric_columns] = combined_data[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Drop rows with NaN values in numeric columns
combined_data.replace([np.inf, -np.inf], np.nan, inplace=True)
combined_data.fillna(0, inplace=True)

# Display the final combined data
print("Final combined data:")
combined_data.head()
# Out:
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2018.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2019.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2015.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2020.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2014.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2005.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_202201030000_202302201721.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2008.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2016.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2006.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2009.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2010.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2021.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2007.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2013.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2012.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2011.csv
# Loading file: /root/github/CTI_Scripts/py_scripts/backtesting/historical_data/USDJPY/DAT_MT_USDJPY_M1_2017.csv
# Final combined data:
#                            DATE   TIME    OPEN    HIGH     LOW   CLOSE  \
# datetime
# 2005-01-03 01:48:00  2005.01.03  01:48  102.58  102.58  102.58  102.58
# 2005-01-03 01:53:00  2005.01.03  01:53  102.58  102.91  102.58  102.90
# 2005-01-03 01:54:00  2005.01.03  01:54  102.91  102.91  102.91  102.91
# 2005-01-03 01:55:00  2005.01.03  01:55  102.90  102.90  102.90  102.90
# 2005-01-03 01:56:00  2005.01.03  01:56  102.88  102.88  102.85  102.86
#
#                      TICKVOL  VOL  SPREAD
# datetime
# 2005-01-03 01:48:00        0  0.0     0.0
# 2005-01-03 01:53:00        0  0.0     0.0
# 2005-01-03 01:54:00        0  0.0     0.0
# 2005-01-03 01:55:00        0  0.0     0.0
# 2005-01-03 01:56:00        0  0.0     0.0

# %%
combined_data_1m = combined_data

combined_data_1m = combined_data_1m.drop(columns=['DATE', 'TIME'])

combined_data_1m.head()
# Out:
#                        OPEN    HIGH     LOW   CLOSE  TICKVOL  VOL  SPREAD
# datetime
# 2005-01-03 01:48:00  102.58  102.58  102.58  102.58        0  0.0     0.0
# 2005-01-03 01:53:00  102.58  102.91  102.58  102.90        0  0.0     0.0
# 2005-01-03 01:54:00  102.91  102.91  102.91  102.91        0  0.0     0.0
# 2005-01-03 01:55:00  102.90  102.90  102.90  102.90        0  0.0     0.0
# 2005-01-03 01:56:00  102.88  102.88  102.85  102.86        0  0.0     0.0

# %%
# Calculate indicators
aroon_length = 14
ema_length = 50
stoch_rsi_length = 14
stoch_rsi_smoothK = 3
stoch_rsi_smoothD = 3
supertrend_length = 14
supertrend_mult = 3.0
kc_length = 20
kc_scalar = 1.5
atr_length = 14

# %%
combined_data_1m['AROON-OSC'] = ta.aroon(
    combined_data_1m['HIGH'],
    combined_data_1m['LOW'],
    length=aroon_length
)[f'AROONOSC_{aroon_length}'].round(decimals)
combined_data_1m['EMA_50'] = ta.ema(combined_data_1m['CLOSE'], length=ema_length).round(decimals)
combined_data_1m['STOCH-RSId'] = ta.stochrsi(
    combined_data_1m['CLOSE'],
    length=stoch_rsi_length,
    smoothK=stoch_rsi_smoothK,
    smoothD=stoch_rsi_smoothD
)[f'STOCHRSId_{stoch_rsi_length}_{stoch_rsi_length}_{stoch_rsi_smoothK}_{stoch_rsi_smoothD}'].round(2)
combined_data_1m['STOCH-RSIk'] = ta.stochrsi(
    combined_data_1m['CLOSE'],
    length=stoch_rsi_length,
    smoothK=stoch_rsi_smoothK,
    smoothD=stoch_rsi_smoothD
)[f'STOCHRSIk_{stoch_rsi_length}_{stoch_rsi_length}_{stoch_rsi_smoothK}_{stoch_rsi_smoothD}'].round(2)
combined_data_1m['SUPERTREND'] = ta.supertrend(
    combined_data_1m['HIGH'],
    combined_data_1m['LOW'],
    combined_data_1m['CLOSE'],
    length=supertrend_length,
    multiplier=supertrend_mult
)[f'SUPERT_{supertrend_length}_{supertrend_mult}'].round(decimals)
combined_data_1m['Keltner-Upper'] = ta.kc(
    high=combined_data_1m['HIGH'],
    low=combined_data_1m['LOW'],
    close=combined_data_1m['CLOSE'],
    length=kc_length,
    scalar=kc_scalar
)[f'KCUe_{kc_length}_{kc_scalar}'].round(decimals)
combined_data_1m['Keltner-Basis'] = ta.kc(
    high=combined_data_1m['HIGH'],
    low=combined_data_1m['LOW'],
    close=combined_data_1m['CLOSE'],
    length=kc_length,
    scalar=kc_scalar
)[f'KCBe_{kc_length}_{kc_scalar}'].round(decimals)
combined_data_1m['Keltner-Lower'] = ta.kc(
    high=combined_data_1m['HIGH'],
    low=combined_data_1m['LOW'],
    close=combined_data_1m['CLOSE'],
    length=kc_length,
    scalar=kc_scalar
)[f'KCLe_{kc_length}_{kc_scalar}'].round(decimals)
combined_data_1m['ATR'] = ta.atr(
    high=combined_data_1m['HIGH'],
    low=combined_data_1m['LOW'],
    close=combined_data_1m['CLOSE'],
    length=atr_length
).round(decimals)



# Drop rows with NaN values (due to indicator calculation)
combined_data_1m.dropna(inplace=True)

# Display the data with indicators
print("Data with indicators:")
combined_data_1m.head()
# Out:
# Data with indicators:
#                        OPEN    HIGH     LOW   CLOSE  TICKVOL  VOL  SPREAD  \
# datetime
# 2005-01-03 02:45:00  102.73  102.74  102.73  102.74        0  0.0     0.0
# 2005-01-03 02:46:00  102.75  102.75  102.70  102.74        0  0.0     0.0
# 2005-01-03 02:47:00  102.75  102.76  102.72  102.73        0  0.0     0.0
# 2005-01-03 02:48:00  102.74  102.79  102.74  102.77        0  0.0     0.0
# 2005-01-03 02:49:00  102.76  102.79  102.76  102.76        0  0.0     0.0
#
#                      AROON-OSC  EMA_50  STOCH-RSId  STOCH-RSIk  SUPERTREND  \
# datetime
# 2005-01-03 02:45:00     -85.71  102.86        8.37       20.01      102.79
# 2005-01-03 02:46:00     -78.57  102.85       20.49       36.39      102.79
# 2005-01-03 02:47:00     -64.29  102.85       34.30       46.52      102.79
# 2005-01-03 02:48:00     -64.29  102.85       49.28       64.92      102.79
# 2005-01-03 02:49:00     -57.14  102.84       63.30       78.45      102.79
#
#                      Keltner-Upper  Keltner-Basis  Keltner-Lower   ATR
# datetime
# 2005-01-03 02:45:00         102.84         102.80         102.75  0.03
# 2005-01-03 02:46:00         102.84         102.79         102.74  0.03
# 2005-01-03 02:47:00         102.84         102.78         102.73  0.03
# 2005-01-03 02:48:00         102.84         102.78         102.73  0.04
# 2005-01-03 02:49:00         102.83         102.78         102.73  0.03

# %%
plotly_data = combined_data_1m.loc['2021-01-01':'2021-01-31']

# Create a Plotly figure with subplots
fig = make_subplots(rows=4, cols=1, shared_xaxes=True, 
                    vertical_spacing=0.02, 
                    row_heights=[0.10, 0.75, 0.15, 0.15],
                    subplot_titles=('ATR 50',
                                    f'{symbol} 1m | EMA 50 | Supertrend 50, 3.0 | Keltner Channels 20, 1.5',
                                    'Aroon Oscillator 50',
                                    'Stochastic RSI 14, 3, 3'
                                )
                            )

# Add candlestick chart
fig.add_trace(go.Candlestick(x=plotly_data.index,
                             open=plotly_data['OPEN'],
                             high=plotly_data['HIGH'],
                             low=plotly_data['LOW'],
                             close=plotly_data['CLOSE'],
                             ),
            row=2, col=1)

# Add ATR to top of chart
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['ATR'],
    mode='lines',
    line=go.scatter.Line(color='yellow'),
    name='ATR'
), row=1, col=1)
# Add indicators to candlestick chart
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['EMA_50'],
    mode='lines',
    line=go.scatter.Line(color='red'),
    name='EMA 50'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['SUPERTREND'],
    mode='lines',
    line=go.scatter.Line(color='green'),
    name='SUPERTREND'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['Keltner-Upper'],
    mode='lines',
    line=go.scatter.Line(color='blue'),
    name='Keltner-Upper'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['Keltner-Basis'],
    mode='lines',
    line=go.scatter.Line(color='blue', dash='dash'),
    name='Keltner-Basis'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['Keltner-Lower'],
    mode='lines',
    line=go.scatter.Line(color='blue'),
    name='Keltner-Lower'
), row=2, col=1)

# Add Aroon Oscillator
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['AROON-OSC'],
    mode='lines',
    line=go.scatter.Line(color='purple'),
    name='Aroon Oscillator'
), row=3, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[0] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='grey', dash='dash'),
    name='Aroon Osc Zero Line'
), row=3, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[60] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='blue', dash='dash'),
    name='Aroon Osc Mid Line'
), row=3, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[-60] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='blue', dash='dash'),
    name='Aroon Osc Upper Line'
), row=3, col=1)

# Add Stochastic RSI
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['STOCH-RSId'],
    mode='lines',
    line=go.scatter.Line(color='orange'),
    name='Stochastic RSI %D'
), row=4, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['STOCH-RSIk'],
    mode='lines',
    line=go.scatter.Line(color='blue'),
    name='Stochastic RSI %K'
), row=4, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[20] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='red', dash='dash'),
    name='Oversold Threshold'
), row=4, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[80] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='green', dash='dash'),
    name='Overbought Threshold'
), row=4, col=1)


fig.update_layout(
    title='EURUSD 1m Candlestick Chart with Indicators January 2021',
    xaxis2=dict(
        rangeslider=dict(visible=False),
        rangebreaks=[
            dict(bounds=["sat", "mon"]),  # hide weekends
            dict(values=["2021-01-08 17:00", "2021-01-10 17:00"])
        ]
    ),
    yaxis=dict(title='Price', autorange=True),
    dragmode='zoom',
    uirevision='dynamic',
)

fig.write_html(f'./plotly/test_plot_{symbol}_1m.html')

# %%
combined_data_5m = combined_data.resample('5min').agg({
    'OPEN': 'first',
    'HIGH': 'max',
    'LOW': 'min',
    'CLOSE': 'last',
    'TICKVOL': 'sum',  # Aggregate tick volumes
    'VOL': 'sum',      # Aggregate actual volumes
    'SPREAD': 'mean',  # Average spread
}).dropna()

# Ensure datetime is set as the index
combined_data_5m.reset_index(inplace=True)  # Ensure 'datetime' is a column
combined_data_5m['datetime'] = pd.to_datetime(combined_data_5m['datetime'])  # Convert to datetime
combined_data_5m.set_index('datetime', inplace=True)  # Set as index

# Display the resampled data
combined_data_5m.head()
# Out:
#                        OPEN    HIGH     LOW   CLOSE  TICKVOL  VOL  SPREAD
# datetime
# 2005-01-03 01:45:00  102.58  102.58  102.58  102.58        0  0.0     0.0
# 2005-01-03 01:50:00  102.58  102.91  102.58  102.91        0  0.0     0.0
# 2005-01-03 01:55:00  102.90  102.90  102.79  102.80        0  0.0     0.0
# 2005-01-03 02:00:00  102.81  102.89  102.80  102.87        0  0.0     0.0
# 2005-01-03 02:05:00  102.88  102.91  102.88  102.90        0  0.0     0.0

# %%
combined_data_5m['AROON-OSC'] = ta.aroon(
    combined_data_5m['HIGH'],
    combined_data_5m['LOW'],
    length=aroon_length
)[f'AROONOSC_{aroon_length}'].round(2)
combined_data_5m['EMA_50'] = ta.ema(combined_data_5m['CLOSE'], length=ema_length).round(decimals)
combined_data_5m['STOCH-RSId'] = ta.stochrsi(
    combined_data_5m['CLOSE'],
    length=stoch_rsi_length,
    smoothK=stoch_rsi_smoothK,
    smoothD=stoch_rsi_smoothD
)[f'STOCHRSId_{stoch_rsi_length}_{stoch_rsi_length}_{stoch_rsi_smoothK}_{stoch_rsi_smoothD}'].round(2)
combined_data_5m['STOCH-RSIk'] = ta.stochrsi(
    combined_data_5m['CLOSE'],
    length=stoch_rsi_length,
    smoothK=stoch_rsi_smoothK,
    smoothD=stoch_rsi_smoothD
)[f'STOCHRSIk_{stoch_rsi_length}_{stoch_rsi_length}_{stoch_rsi_smoothK}_{stoch_rsi_smoothD}'].round(2)
combined_data_5m['SUPERTREND'] = ta.supertrend(
    combined_data_5m['HIGH'],
    combined_data_5m['LOW'],
    combined_data_5m['CLOSE'],
    length=supertrend_length,
    multiplier=supertrend_mult
)[f'SUPERT_{supertrend_length}_{supertrend_mult}'].round(decimals)
combined_data_5m['Keltner-Upper'] = ta.kc(
    high=combined_data_5m['HIGH'],
    low=combined_data_5m['LOW'],
    close=combined_data_5m['CLOSE'],
    length=kc_length,
    scalar=kc_scalar
)[f'KCUe_{kc_length}_{kc_scalar}'].round(decimals)
combined_data_5m['Keltner-Basis'] = ta.kc(
    high=combined_data_5m['HIGH'],
    low=combined_data_5m['LOW'],
    close=combined_data_5m['CLOSE'],
    length=kc_length,
    scalar=kc_scalar
)[f'KCBe_{kc_length}_{kc_scalar}'].round(decimals)
combined_data_5m['Keltner-Lower'] = ta.kc(
    high=combined_data_5m['HIGH'],
    low=combined_data_5m['LOW'],
    close=combined_data_5m['CLOSE'],
    length=kc_length,
    scalar=kc_scalar
)[f'KCLe_{kc_length}_{kc_scalar}'].round(decimals)
combined_data_5m['ATR'] = ta.atr(
    high=combined_data_5m['HIGH'],
    low=combined_data_5m['LOW'],
    close=combined_data_5m['CLOSE'],
    length=atr_length
).round(decimals)


# Drop rows with NaN values (due to indicator calculation)
combined_data_5m.dropna(inplace=True)

# Display the data with indicators
print("5 min Data with indicators:")
combined_data_5m.head()
# Out:
# 5 min Data with indicators:
#                        OPEN    HIGH     LOW   CLOSE  TICKVOL  VOL  SPREAD  \
# datetime
# 2005-01-03 05:50:00  102.73  102.76  102.72  102.74        0  0.0     0.0
# 2005-01-03 05:55:00  102.75  102.76  102.71  102.74        0  0.0     0.0
# 2005-01-03 06:00:00  102.75  102.79  102.73  102.76        0  0.0     0.0
# 2005-01-03 06:05:00  102.75  102.79  102.75  102.79        0  0.0     0.0
# 2005-01-03 06:10:00  102.78  102.79  102.74  102.78        0  0.0     0.0
#
#                      AROON-OSC  EMA_50  STOCH-RSId  STOCH-RSIk  SUPERTREND  \
# datetime
# 2005-01-03 05:50:00      21.43  102.78       48.51       38.84      102.87
# 2005-01-03 05:55:00      21.43  102.77       39.55       39.18      102.87
# 2005-01-03 06:00:00      21.43  102.77       44.43       55.26      102.87
# 2005-01-03 06:05:00      21.43  102.77       55.80       72.96      102.87
# 2005-01-03 06:10:00      21.43  102.77       71.42       86.04      102.87
#
#                      Keltner-Upper  Keltner-Basis  Keltner-Lower   ATR
# datetime
# 2005-01-03 05:50:00         102.83         102.74         102.65  0.06
# 2005-01-03 05:55:00         102.83         102.74         102.65  0.06
# 2005-01-03 06:00:00         102.83         102.74         102.66  0.06
# 2005-01-03 06:05:00         102.83         102.75         102.66  0.06
# 2005-01-03 06:10:00         102.84         102.75         102.67  0.06

# %%
data_5m_2018 = combined_data_5m.loc['2018-01-01':'2018-12-31']

matching_rows = data_5m_2018[data_5m_2018['CLOSE'] == data_5m_2018['SUPERTREND']]
print(f'Number of matching rows: {len(matching_rows)}')
matching_rows.head()
# Out:
# Number of matching rows: 68
#                         OPEN     HIGH      LOW   CLOSE  TICKVOL  VOL  SPREAD  \
# datetime
# 2018-01-08 01:15:00  113.216  113.222  113.209  113.21        0  0.0     0.0
# 2018-01-18 00:10:00  111.367  111.372  111.336  111.34        0  0.0     0.0
# 2018-01-23 09:55:00  110.418  110.427  110.331  110.36        0  0.0     0.0
# 2018-01-29 03:55:00  108.908  108.908  108.867  108.87        0  0.0     0.0
# 2018-02-11 21:50:00  108.700  108.742  108.699  108.73        0  0.0     0.0
#
#                      AROON-OSC  EMA_50  STOCH-RSId  STOCH-RSIk  SUPERTREND  \
# datetime
# 2018-01-08 01:15:00      42.86  113.19        7.13        0.04      113.21
# 2018-01-18 00:10:00     -42.86  111.34        5.17        6.86      111.34
# 2018-01-23 09:55:00     -21.43  110.50       68.87       45.92      110.36
# 2018-01-29 03:55:00    -100.00  108.87       10.54        6.52      108.87
# 2018-02-11 21:50:00      85.71  108.68       99.02      100.00      108.73
#
#                      Keltner-Upper  Keltner-Basis  Keltner-Lower   ATR
# datetime
# 2018-01-08 01:15:00         113.24         113.21         113.19  0.02
# 2018-01-18 00:10:00         111.42         111.37         111.33  0.03
# 2018-01-23 09:55:00         110.54         110.45         110.36  0.06
# 2018-01-29 03:55:00         108.99         108.91         108.83  0.05
# 2018-02-11 21:50:00         108.72         108.67         108.62  0.04

# %%
plotly_data = combined_data_5m.loc['2021-01-01':'2021-01-31']

# Create a Plotly figure with subplots
fig = make_subplots(rows=4, cols=1, shared_xaxes=True, 
                    vertical_spacing=0.04, 
                    row_heights=[0.10, 0.75, 0.15, 0.15],
                    subplot_titles=(
                        'ATR 14',
                        f'{symbol} 5m | EMA 50 | Supertrend 50, 3.0 | Keltner Channels 20, 1.5',
                        'Aroon Oscillator 50',
                        'Stochastic RSI 14, 3, 3'
                    )
                )

# Add candlestick chart
fig.add_trace(go.Candlestick(x=plotly_data.index,
                             open=plotly_data['OPEN'],
                             high=plotly_data['HIGH'],
                             low=plotly_data['LOW'],
                             close=plotly_data['CLOSE'],
                             ),
            row=2, col=1)

# Add ATR to top of chart
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['ATR'],
    mode='lines',
    line=go.scatter.Line(color='yellow'),
    name='ATR'
), row=1, col=1)
# Add indicators to candlestick chart
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['EMA_50'],
    mode='lines',
    line=go.scatter.Line(color='red'),
    name='EMA 50'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['SUPERTREND'],
    mode='lines',
    line=go.scatter.Line(color='green'),
    name='SUPERTREND'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['Keltner-Upper'],
    mode='lines',
    line=go.scatter.Line(color='blue'),
    name='Keltner-Upper'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['Keltner-Basis'],
    mode='lines',
    line=go.scatter.Line(color='blue', dash='dash'),
    name='Keltner-Basis'
), row=2, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['Keltner-Lower'],
    mode='lines',
    line=go.scatter.Line(color='blue'),
    name='Keltner-Lower'
), row=2, col=1)

# Add Aroon Oscillator
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['AROON-OSC'],
    mode='lines',
    line=go.scatter.Line(color='purple'),
    name='Aroon Oscillator'
), row=3, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[0] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='grey', dash='dash'),
    name='Aroon Osc Zero Line'
), row=3, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[60] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='blue', dash='dash'),
    name='Aroon Osc Mid Line'
), row=3, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[-60] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='blue', dash='dash'),
    name='Aroon Osc Upper Line'
), row=3, col=1)

# Add Stochastic RSI
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['STOCH-RSId'],
    mode='lines',
    line=go.scatter.Line(color='orange'),
    name='Stochastic RSI %D'
), row=4, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=plotly_data['STOCH-RSIk'],
    mode='lines',
    line=go.scatter.Line(color='blue'),
    name='Stochastic RSI %K'
), row=4, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[20] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='red', dash='dash'),
    name='Oversold Threshold'
), row=4, col=1)
fig.add_trace(go.Scatter(
    x=plotly_data.index,
    y=[80] * len(plotly_data),
    mode='lines',
    line=go.scatter.Line(color='green', dash='dash'),
    name='Overbought Threshold'
), row=4, col=1)


fig.update_layout(
    title='EURUSD 5m Candlestick Chart with Indicators January 2021',
    xaxis2=dict(
        rangeslider=dict(visible=False),
        rangebreaks=[
            dict(bounds=["sat", "mon"]),  # hide weekends
            dict(values=["2021-01-08 17:00", "2021-01-10 17:00"])
        ]
    ),
    yaxis=dict(title='Price', autorange=True),
    dragmode='zoom',
    uirevision='dynamic',
)

fig.write_html(f'./plotly/test_plot_{symbol}_5m.html')

# %%
class SuperTrendStrategy(bt.Strategy):
    params = dict(
        risk_per_trade=0.0025,
        rr_ratio=2.8,
    )

    def __init__(self):
        self.buy_order = None
        self.sell_order = None
        self.stop_order = None
        self.trade_log = []
        self.open_trades = {}
        # self.data_1m = self.datas[0]
        # self.data_5m = self.datas[1]
        # Indicators
        self.supertrend = self.data.supertrend
        self.ema = self.data.ema_50
        self.aroon = self.data.aroon_osc
        self.stoch_rsi_d = self.data.stoch_rsi_d
        self.stoch_rsi_k = self.data.stoch_rsi_k
        self.kc_upper = self.data.keltner_upper
        self.kc_basis = self.data.keltner_basis
        self.kc_lower = self.data.keltner_lower
        self.atr = self.data.atr
        

    def log(self, *args, dt=None):
        '''Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.date(0)
        print('%s, %s' % (dt.isoformat(), ', '.join(map(str, args))))
    
    def calculate_take_profit(self, current_price, stop_loss, is_buy):
            if is_buy:
                return current_price + ((current_price - stop_loss) * self.params.rr_ratio)
            else:
                return current_price - ((stop_loss - current_price) * self.params.rr_ratio)

    def calculate_volume(self, current_price, stop_loss):
        # Calculate position size based on risk
        account_balance = self.broker.getvalue()
        risk_amount = account_balance * self.params.risk_per_trade
        stop_loss_distance = abs(current_price - stop_loss)

        # Ensure stop loss distance is not zero or too small
        if stop_loss_distance == 0:
            self.log(f"Skipping trade due to stop loss distance being 0")
            return None

        # Calculate volume in lots (1 lot = 100,000 units)
        volume = risk_amount / stop_loss_distance / multiplier
        # if volume < 0:
        #     self.log(f"Skipping trade due to invalid volume - Volume: {volume}")
        #     return None
        # self.log(f"Calculated volume: {volume:.2f} lots")
        return round(volume, 2)           

    def next(self):        
        if self.position:
            self.adjust_trailing_stop()
            return
        
        # Fetch values
        current_price = self.data.close[0]
        current_high_range = self.data.high.get(size=5)
        current_low_range = self.data.low.get(size=5)
        recent_highs = self.data.high.get(size=10)
        recent_lows = self.data.low.get(size=10)

        if len(current_high_range) < 5 or len(current_low_range) < 5:
            self.log("Not enough data points to calculate current high and low.")
            return
        current_high = max(current_high_range)
        current_low = min(current_low_range)


        # Check if there are enough data points
        if len(recent_highs) < 10 or len(recent_lows) < 10:
            self.log("Not enough data points to calculate recent high and low.")
            return
        recent_high = max(recent_highs)
        recent_low = min(recent_lows)
        
        recent_high_index = self.data.high.get(size=10).index(recent_high)
        recent_low_index = self.data.low.get(size=10).index(recent_low)

        ago_recent_high = -(10 - recent_high_index)
        ago_recent_low = -(10 - recent_low_index)

        kc_upper_at_recent_high = self.kc_upper[ago_recent_high]
        kc_lower_at_recent_low = self.kc_lower[ago_recent_low]
        kc_basis = self.kc_basis[0]
        atr = self.atr[0]
        supertrend = self.supertrend[0]
        ema = self.ema[0]
        aroon = self.aroon[0]
        stoch_k = self.stoch_rsi_k[0]
        stoch_k_recent_max = max(self.stoch_rsi_k.get(size=5))
        stoch_k_recent_min = min(self.stoch_rsi_k.get(size=5))
        stoch_d = self.stoch_rsi_d[0]

        # Set Aroon Oscillator threshold
        aroon_threshold = 40

        # Log indicator values
        # print(f"Current Price: {current_price:.5f}, Supertrend: {supertrend:.5f}, EMA: {ema:.5f}, Aroon: {aroon:.2f}, Stoch K: {stoch_k:.2f}, Stoch D: {stoch_d:.2f}")

        # Calculate stop loss and take profit
        stop_loss = round(supertrend, decimals)
        take_profit_buy = self.calculate_take_profit(current_price, stop_loss, is_buy=True)
        take_profit_sell = self.calculate_take_profit(current_price, stop_loss, is_buy=False)
        volume = self.calculate_volume(current_price, stop_loss)
        stop_trail = abs(current_price - stop_loss)

        if volume is None:
            self.log("Volume calculation resulted in None.")
            return
        
        
        # Long entry
        if (
            not self.buy_order 
            and not self.sell_order
            and current_price > supertrend 
            and current_price > ema
            and recent_high > kc_upper_at_recent_high
            and current_low <= kc_basis 
            and aroon > aroon_threshold 
            and stoch_k_recent_min < 30 
            and stoch_d < stoch_k
        ):
            main_order = self.buy(
                size=volume,
                exectype=bt.Order.Market,
                transmit=False
            )
            self.stop_order = self.sell(
                size=volume, exectype=bt.Order.StopTrail,
                price=stop_loss,
                trailamount=stop_trail,
                parent=main_order,
                transmit=False
            )
            self.profit_order = self.sell(
                size=volume, exectype=bt.Order.Limit,
                price=take_profit_buy,
                parent=main_order,
                transmit=True
            )
            self.buy_order = main_order

        # Short entry
        elif (
            not self.sell_order
            and not self.buy_order
            and current_price < supertrend 
            and current_price < ema 
            and recent_low < kc_lower_at_recent_low
            and current_high >= kc_basis
            and aroon < -aroon_threshold
            and stoch_k_recent_max > 70 
            and stoch_d > stoch_k
        ):
            main_order = self.sell(
                size=volume,
                exectype=bt.Order.Market,
                transmit=False
            )
            self.stop_order = self.buy(
                size=volume,
                exectype=bt.Order.StopTrail,
                price=stop_loss,
                trailamount=stop_trail,
                parent=main_order,
                transmit=False
            )
            self.profit_order = self.buy(
                size=volume, exectype=bt.Order.Limit,
                price=take_profit_sell,
                parent=main_order,
                transmit=True
            )
            self.sell_order = main_order

    def adjust_trailing_stop(self):
        """Adjust the trailing stop loss to follow the Supertrend."""
        if self.position:
            new_stop = round(self.supertrend[0], decimals)
            profit_price = self.profit_order.price

            if self.position.size > 0:  # Long position
                if self.stop_order and new_stop > self.stop_order.price:
                    self.log(
                        f"Updating trailing stop for BUY position to \
{new_stop} order number {self.stop_order.ref}"
                    )
                    self.cancel(self.stop_order)  # Cancel the current stop order
                    self.stop_order = self.sell(  # Create a new stop order
                        size=self.position.size,
                        price=new_stop,
                        exectype=bt.Order.Stop,
                    )

            elif self.position.size < 0:  # Short position
                if self.stop_order and new_stop < self.stop_order.price:
                    self.log(
                        f"Updating trailing stop for SELL position to \
{new_stop} order number {self.stop_order.ref}"
                    )
                    self.cancel(self.stop_order)  # Cancel the current stop order
                    self.stop_order = self.buy(  # Create a new stop order
                        size=self.position.size,
                        price=new_stop,
                        exectype=bt.Order.Stop,
                    )

    def log_trade(self, trade_info):
        """Log a trade into the trade log."""
        self.trade_log.append(trade_info)

    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            return

        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(f"BUY EXECUTED {order.ref}")
                self.buy_order = None  # Clear buy order
                self.open_trades[order.ref] = {
                    "TRADE NUMBER": len(self.trade_log) + 1,
                    "SYMBOL": "EURUSD",
                    "OPEN TIME": self.data.datetime.datetime(0),
                    "VOLUME": self.calculate_volume(self.data.close[0], self.supertrend[0]),
                    "SIDE": "BUY",
                    "OPEN PRICE": round(order.executed.price, decimals),
                    "STOP LOSS": round(self.supertrend[0], decimals),
                    "TAKE PROFIT": round(self.calculate_take_profit(self.data.close[0], self.supertrend[0], is_buy=True), decimals),
                }
                self.log_trade(self.open_trades[order.ref])
            elif order.issell():
                self.log(f"SELL EXECUTED {order.ref}")
                self.sell_order = None  # Clear sell order
                self.open_trades[order.ref] = {
                    "TRADE NUMBER": len(self.trade_log) + 1,
                    "SYMBOL": symbol.upper(),
                    "OPEN TIME": self.data.datetime.datetime(0),
                    "VOLUME": self.calculate_volume(self.data.close[0], self.supertrend[0]),
                    "SIDE": "SELL",
                    "OPEN PRICE": round(order.executed.price, decimals),
                    "STOP LOSS": round(self.supertrend[0], decimals),
                    "TAKE PROFIT": round(self.calculate_take_profit(self.data.close[0], self.supertrend[0], is_buy=False), decimals),
                    "CLOSE TIME": None,
                    "CLOSE PRICE": None,
                    "PROFIT": None,
                    "RUNNING BALANCE": None,
                }
                self.log_trade(self.open_trades[order.ref])

            # Check if the order is closing an existing trade
            if order.exectype in [bt.Order.Stop, bt.Order.Limit] and order.parent:
                parent_ref = order.parent.ref
                if parent_ref in self.open_trades:
                    trade_info = self.open_trades.pop(parent_ref, {})
                    trade_info.update({
                        "CLOSE TIME": self.data.datetime.datetime(0),
                        "CLOSE PRICE": round(order.executed.price, decimals),
                        "PROFIT": round(order.executed.pnl, 2),
                        "RUNNING BALANCE": round(self.broker.getvalue(), 2),
                    })
                    self.log_trade(trade_info)
                    self.log(f"TRADE CLOSED {parent_ref} by {order.ref}, Gross PnL={order.executed.pnl:.2f}")

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            if order.status == order.Canceled:
                self.log(f'Order Canceled: {order.ref}')
            elif order.status == order.Margin:
                self.log(f"Margin call: Not enough margin for order {order.ref}")
            elif order.status == order.Rejected:
                self.log(f"Order rejected: {order.ref}")

        self.order = None

    # def notify_trade(self, trade):
    #     if not trade.isclosed:
    #         return

    #     self.log(f"TRADE CLOSED trade.myref={final_ref}, Gross PnL={trade.pnl:.2f}")

    #     trade_info = self.open_trades.pop(final_ref, {})
        
    #     trade_info.update({
    #         "CLOSE TIME": self.data.datetime.datetime(0),
    #         "CLOSE PRICE": round(trade.price, 5),
    #         "PROFIT": round(trade.pnl, 2),
    #         "RUNNING BALANCE": round(self.broker.getvalue(), 2),
    #     })
    #     self.log_trade(trade_info)

    def stop(self):
        # Save trades to a DataFrame at the end of the backtest
        self.trade_df = pd.DataFrame(self.trade_log)

        # Filter out canceled orders
        self.trade_df = self.trade_df[self.trade_df['CLOSE PRICE'].notna()]

        # Remove duplicates
        self.trade_df = self.trade_df.drop_duplicates()

        self.trade_df.to_csv(
            f'./back_test_data/{symbol}_{year}_to_{end_year}_5m_ST{supertrend_length}_EMA{ema_length}_\
AROON{aroon_length}.csv',
            index=False
        )

# %%
class CustomBroker(bt.brokers.BackBroker):
    def __init__(self, starting_balance=2500, profit_target=0.1, max_loss=0.06,  *args, **kwargs):
        super(CustomBroker, self).__init__(*args, **kwargs)
        self.starting_balance = starting_balance
        self.profit_target = profit_target
        self.max_loss = max_loss
        self.absolute_profit_target = self.starting_balance * (1 + self.profit_target)
        self.absolute_max_loss = self.starting_balance * (1 - self.max_loss)
        self.set_cash(self.starting_balance)

    def next(self):
        super(CustomBroker, self).next()
        current_value = self.getvalue()
        # print(f"Current value: {current_value:.2f}")
        
        if current_value >= self.absolute_profit_target:
            self.starting_balance *= 2
            self.set_cash(self.starting_balance)
            self.absolute_profit_target = self.starting_balance * (1 + self.profit_target)
            self.absolute_max_loss = self.starting_balance * (1 - self.max_loss)
            print('################################################################################')
            print(f'Profit target hit. New starting balance: {self.starting_balance}')
            print('################################################################################')
        
        elif current_value <= self.absolute_max_loss:
            self.set_cash(self.starting_balance)
            print('################################################################################')
            print(f'Max loss hit. Resetting to starting balance: {self.starting_balance}')
            print('################################################################################')

# %%
# Convert the pandas DataFrame to a Backtrader data feed
class PandasData(bt.feeds.PandasData):
    lines = (
        'ema_50',
        'stoch_rsi_k',
        'stoch_rsi_d',
        'supertrend',
        'aroon_osc',
        'keltner_upper',
        'keltner_basis',
        'keltner_lower',
        'atr',
    )
    params = (
        ('datetime', None),
        ('open', 'OPEN'),
        ('high', 'HIGH'),
        ('low', 'LOW'),
        ('close', 'CLOSE'),
        ('volume', 'VOL'),
        ('ema_50', 'EMA_50'),
        ('stoch_rsi_k', 'STOCH-RSIk'),
        ('stoch_rsi_d', 'STOCH-RSId'),
        ('supertrend', 'SUPERTREND'),
        ('aroon_osc', 'AROON-OSC'),
        ('keltner_upper', 'Keltner-Upper'),
        ('keltner_basis', 'Keltner-Basis'),
        ('keltner_lower', 'Keltner-Lower'),
        ('atr', 'ATR'),
    )

test_data_1m = combined_data_1m.loc[f'{year}-01-01':f'{end_year}-12-31']
test_data_5m = combined_data_5m.loc[f'{year}-01-01':f'{end_year}-12-31']

data_feed = PandasData(dataname=test_data_5m)

comm_info = bt.CommInfoBase(
    commission=0.02,
    leverage=30,
    margin=1 / 30,
    mult=multiplier
)

# Set up the Backtrader environment
cerebro = bt.Cerebro()
cerebro.addstrategy(SuperTrendStrategy)
cerebro.adddata(data_feed)

# Use the custom broker
custom_broker = CustomBroker(starting_balance=starting_balance, profit_target=profit_target, max_loss=max_loss)
cerebro.setbroker(custom_broker)
cerebro.broker.addcommissioninfo(comm_info)

# Run the backtest
cerebro.run(style='candlestick')
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# 2011-01-02, Not enough data points to calculate current high and low.
# 2011-01-02, Not enough data points to calculate current high and low.
# 2011-01-02, Not enough data points to calculate current high and low.
# 2011-01-02, Not enough data points to calculate current high and low.
# 2011-01-02, Not enough data points to calculate recent high and low.
# 2011-01-02, Not enough data points to calculate recent high and low.
# 2011-01-02, Not enough data points to calculate recent high and low.
# 2011-01-02, Not enough data points to calculate recent high and low.
# 2011-01-02, Not enough data points to calculate recent high and low.
# 2011-01-03, SELL EXECUTED 111088
# 2011-01-03, BUY EXECUTED 111089
# 2011-01-03, TRADE CLOSED 111088 by 111089, Gross PnL=-5.00
# 2011-01-03, Order Canceled: 111090
# 2011-01-03, BUY EXECUTED 111091
# 2011-01-03, Updating trailing stop for BUY position to 81.32 order number 111092
# 2011-01-03, Order Canceled: 111092
# 2011-01-03, Order Canceled: 111093
# 2011-01-03, Updating trailing stop for BUY position to 81.33 order number 111094
# 2011-01-03, Order Canceled: 111094
# 2011-01-03, Updating trailing stop for BUY position to 81.35 order number 111095
# 2011-01-03, Order Canceled: 111095
# 2011-01-03, Updating trailing stop for BUY position to 81.36 order number 111096
# 2011-01-03, Order Canceled: 111096
# 2011-01-03, Updating trailing stop for BUY position to 81.37 order number 111097
# 2011-01-03, Order Canceled: 111097
# 2011-01-03, SELL EXECUTED 111098
# 2011-01-03, BUY EXECUTED 111099
# 2011-01-03, SELL EXECUTED 111100
# 2011-01-03, TRADE CLOSED 111099 by 111100, Gross PnL=-5.52
# 2011-01-03, Order Canceled: 111101
# 2011-01-03, BUY EXECUTED 111102
# 2011-01-03, Updating trailing stop for BUY position to 81.61 order number 111103
# 2011-01-03, Order Canceled: 111103
# 2011-01-03, Order Canceled: 111104
# 2011-01-03, Updating trailing stop for BUY position to 81.63 order number 111105
# 2011-01-03, Order Canceled: 111105
# 2011-01-03, Updating trailing stop for BUY position to 81.64 order number 111106
# 2011-01-03, Order Canceled: 111106
# 2011-01-03, Updating trailing stop for BUY position to 81.65 order number 111107
# 2011-01-03, Order Canceled: 111107
# 2011-01-03, Updating trailing stop for BUY position to 81.66 order number 111108
# 2011-01-03, Order Canceled: 111108
# 2011-01-03, Updating trailing stop for BUY position to 81.67 order number 111109
# 2011-01-03, Order Canceled: 111109
# 2011-01-03, Updating trailing stop for BUY position to 81.68 order number 111110
# 2011-01-03, Order Canceled: 111110
# 2011-01-03, SELL EXECUTED 111111
# 2011-01-03, BUY EXECUTED 111112
# 2011-01-03, Updating trailing stop for BUY position to 81.84 order number 111113
# 2011-01-03, Order Canceled: 111113
# 2011-01-03, Order Canceled: 111114
# 2011-01-03, Updating trailing stop for BUY position to 81.85 order number 111115
# 2011-01-03, Order Canceled: 111115
# 2011-01-03, Updating trailing stop for BUY position to 81.89 order number 111116
# 2011-01-03, Order Canceled: 111116
# 2011-01-03, Updating trailing stop for BUY position to 81.93 order number 111117
# 2011-01-03, Order Canceled: 111117
# 2011-01-03, Updating trailing stop for BUY position to 81.95 order number 111118
# 2011-01-03, Order Canceled: 111118
# 2011-01-03, Updating trailing stop for BUY position to 81.97 order number 111119
# 2011-01-03, Order Canceled: 111119
# 2011-01-03, Updating trailing stop for BUY position to 81.98 order number 111120
# 2011-01-03, Order Canceled: 111120
# 2011-01-03, Updating trailing stop for BUY position to 82.0 order number 111121
# 2011-01-03, Order Canceled: 111121
# 2011-01-03, Updating trailing stop for BUY position to 82.02 order number 111122
# 2011-01-03, Order Canceled: 111122
# 2011-01-03, Updating trailing stop for BUY position to 82.03 order number 111123
# 2011-01-04, Order Canceled: 111123
# 2011-01-04, Updating trailing stop for BUY position to 82.04 order number 111124
# 2011-01-04, Order Canceled: 111124
# 2011-01-04, Updating trailing stop for BUY position to 82.07 order number 111125
# 2011-01-04, Order Canceled: 111125
# 2011-01-04, Updating trailing stop for BUY position to 82.08 order number 111126
# 2011-01-04, Order Canceled: 111126
# 2011-01-04, Updating trailing stop for BUY position to 82.09 order number 111127
# 2011-01-04, Order Canceled: 111127
# 2011-01-04, Updating trailing stop for BUY position to 82.1 order number 111128
# 2011-01-04, Order Canceled: 111128
# 2011-01-04, Updating trailing stop for BUY position to 82.12 order number 111129
# 2011-01-04, Order Canceled: 111129
# 2011-01-04, SELL EXECUTED 111130
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, BUY EXECUTED 111131
# 2011-01-04, Updating trailing stop for BUY position to 82.11 order number 111132
# 2011-01-04, Order Canceled: 111132
# 2011-01-04, Order Canceled: 111133
# 2011-01-04, Updating trailing stop for BUY position to 82.13 order number 111134
# 2011-01-04, Order Canceled: 111134
# 2011-01-04, SELL EXECUTED 111135
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, SELL EXECUTED 111136
# 2011-01-04, BUY EXECUTED 111137
# 2011-01-04, TRADE CLOSED 111136 by 111137, Gross PnL=-5.46
# 2011-01-04, Order Canceled: 111138
# 2011-01-04, BUY EXECUTED 111139
# 2011-01-04, Updating trailing stop for BUY position to 82.08 order number 111140
# 2011-01-04, Order Canceled: 111140
# 2011-01-04, Order Canceled: 111141
# 2011-01-04, SELL EXECUTED 111142
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, BUY EXECUTED 111143
# 2011-01-04, SELL EXECUTED 111144
# 2011-01-04, TRADE CLOSED 111143 by 111144, Gross PnL=-5.76
# 2011-01-04, Order Canceled: 111145
# 2011-01-04, SELL EXECUTED 111146
# 2011-01-04, Updating trailing stop for SELL position to 81.99 order number 111147
# 2011-01-04, Order Canceled: 111147
# 2011-01-04, Order Canceled: 111148
# 2011-01-04, Updating trailing stop for SELL position to 81.94 order number 111149
# 2011-01-04, Order Canceled: 111149
# 2011-01-04, Updating trailing stop for SELL position to 81.88 order number 111150
# 2011-01-04, Order Canceled: 111150
# 2011-01-04, BUY EXECUTED 111151
# 2011-01-04, BUY EXECUTED 111152
# 2011-01-04, Updating trailing stop for BUY position to 81.94 order number 111153
# 2011-01-04, Order Canceled: 111153
# 2011-01-04, Order Canceled: 111154
# 2011-01-04, Updating trailing stop for BUY position to 81.96 order number 111155
# 2011-01-04, Order Canceled: 111155
# 2011-01-04, Updating trailing stop for BUY position to 81.98 order number 111156
# 2011-01-04, Order Canceled: 111156
# 2011-01-04, Updating trailing stop for BUY position to 81.99 order number 111157
# 2011-01-04, Order Canceled: 111157
# 2011-01-04, Updating trailing stop for BUY position to 82.01 order number 111158
# 2011-01-04, Order Canceled: 111158
# 2011-01-04, SELL EXECUTED 111159
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-04, Skipping trade due to stop loss distance being 0
# 2011-01-04, Volume calculation resulted in None.
# 2011-01-05, Skipping trade due to stop loss distance being 0
# 2011-01-05, Volume calculation resulted in None.
# 2011-01-05, Skipping trade due to stop loss distance being 0
# 2011-01-05, Volume calculation resulted in None.
# 2011-01-05, BUY EXECUTED 111160
# 2011-01-05, Updating trailing stop for BUY position to 82.0 order number 111161
# 2011-01-05, Order Canceled: 111161
# 2011-01-05, Order Canceled: 111162
# 2011-01-05, Updating trailing stop for BUY position to 82.01 order number 111163
# 2011-01-05, Order Canceled: 111163
# 2011-01-05, Updating trailing stop for BUY position to 82.05 order number 111164
# 2011-01-05, Order Canceled: 111164
# 2011-01-05, Updating trailing stop for BUY position to 82.06 order number 111165
# 2011-01-05, Order Canceled: 111165
# 2011-01-05, Updating trailing stop for BUY position to 82.07 order number 111166
# 2011-01-05, Order Canceled: 111166
# 2011-01-05, Updating trailing stop for BUY position to 82.1 order number 111167
# 2011-01-05, Order Canceled: 111167
# 2011-01-05, Updating trailing stop for BUY position to 82.11 order number 111168
# 2011-01-05, Order Canceled: 111168
# 2011-01-05, Updating trailing stop for BUY position to 82.15 order number 111169
# 2011-01-05, Order Canceled: 111169
# 2011-01-05, Updating trailing stop for BUY position to 82.3 order number 111170
# 2011-01-05, Order Canceled: 111170
# 2011-01-05, Updating trailing stop for BUY position to 82.55 order number 111171
# 2011-01-05, Order Canceled: 111171
# 2011-01-05, Updating trailing stop for BUY position to 82.61 order number 111172
# 2011-01-05, Order Canceled: 111172
# 2011-01-05, Updating trailing stop for BUY position to 82.64 order number 111173
# 2011-01-05, Order Canceled: 111173
# 2011-01-05, Updating trailing stop for BUY position to 82.74 order number 111174
# 2011-01-05, Order Canceled: 111174
# 2011-01-05, Updating trailing stop for BUY position to 82.84 order number 111175
# 2011-01-05, Order Canceled: 111175
# 2011-01-05, Updating trailing stop for BUY position to 82.85 order number 111176
# 2011-01-05, Order Canceled: 111176
# 2011-01-05, Updating trailing stop for BUY position to 82.86 order number 111177
# 2011-01-05, Order Canceled: 111177
# 2011-01-05, Updating trailing stop for BUY position to 82.91 order number 111178
# 2011-01-05, Order Canceled: 111178
# 2011-01-05, Updating trailing stop for BUY position to 82.92 order number 111179
# 2011-01-05, Order Canceled: 111179
# 2011-01-05, Updating trailing stop for BUY position to 82.96 order number 111180
# 2011-01-05, Order Canceled: 111180
# 2011-01-05, Updating trailing stop for BUY position to 83.03 order number 111181
# 2011-01-05, Order Canceled: 111181
# 2011-01-05, Updating trailing stop for BUY position to 83.06 order number 111182
# 2011-01-05, Order Canceled: 111182
# 2011-01-05, Updating trailing stop for BUY position to 83.07 order number 111183
# 2011-01-05, Order Canceled: 111183
# 2011-01-05, Updating trailing stop for BUY position to 83.09 order number 111184
# 2011-01-05, Order Canceled: 111184
# 2011-01-05, Updating trailing stop for BUY position to 83.11 order number 111185
# 2011-01-05, Order Canceled: 111185
# 2011-01-05, Updating trailing stop for BUY position to 83.16 order number 111186
# 2011-01-05, Order Canceled: 111186
# ################################################################################
# Profit target hit. New starting balance: 5000
# ################################################################################
# 2011-01-05, Updating trailing stop for BUY position to 83.19 order number 111187
# 2011-01-05, Order Canceled: 111187
# 2011-01-05, Updating trailing stop for BUY position to 83.21 order number 111188
# 2011-01-05, Order Canceled: 111188
# 2011-01-05, SELL EXECUTED 111189
# 2011-01-05, Skipping trade due to stop loss distance being 0
# 2011-01-05, Volume calculation resulted in None.
# 2011-01-05, Skipping trade due to stop loss distance being 0
# 2011-01-05, Volume calculation resulted in None.
# 2011-01-05, Skipping trade due to stop loss distance being 0
# 2011-01-05, Volume calculation resulted in None.
# 2011-01-05, SELL EXECUTED 111190
# 2011-01-05, Updating trailing stop for SELL position to 83.26 order number 111191
# 2011-01-05, Order Canceled: 111191
# 2011-01-05, Order Canceled: 111192
# 2011-01-05, BUY EXECUTED 111193
# 2011-01-05, BUY EXECUTED 111194
# 2011-01-05, SELL EXECUTED 111195
# 2011-01-05, TRADE CLOSED 111194 by 111195, Gross PnL=-13.56
# 2011-01-05, Order Canceled: 111196
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, Volume calculation resulted in None.
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, Volume calculation resulted in None.
# 2011-01-06, SELL EXECUTED 111197
# 2011-01-06, BUY EXECUTED 111198
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, TRADE CLOSED 111197 by 111198, Gross PnL=-10.35
# 2011-01-06, Order Canceled: 111199
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, Volume calculation resulted in None.
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, Volume calculation resulted in None.
# 2011-01-06, BUY EXECUTED 111200
# 2011-01-06, SELL EXECUTED 111201
# 2011-01-06, TRADE CLOSED 111200 by 111201, Gross PnL=-14.82
# 2011-01-06, Order Canceled: 111202
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, Volume calculation resulted in None.
# 2011-01-06, SELL EXECUTED 111203
# 2011-01-06, BUY EXECUTED 111204
# 2011-01-06, TRADE CLOSED 111203 by 111204, Gross PnL=-9.88
# 2011-01-06, Order Canceled: 111205
# 2011-01-06, Skipping trade due to stop loss distance being 0
# 2011-01-06, Volume calculation resulted in None.
# 2011-01-07, BUY EXECUTED 111206
# 2011-01-07, Updating trailing stop for BUY position to 83.4 order number 111207
# 2011-01-07, Order Canceled: 111207
# 2011-01-07, Order Canceled: 111208
# 2011-01-07, Updating trailing stop for BUY position to 83.42 order number 111209
# 2011-01-07, Order Canceled: 111209
# 2011-01-07, Updating trailing stop for BUY position to 83.44 order number 111210
# 2011-01-07, Order Canceled: 111210
# 2011-01-07, Updating trailing stop for BUY position to 83.46 order number 111211
# 2011-01-07, Order Canceled: 111211
# 2011-01-07, Updating trailing stop for BUY position to 83.47 order number 111212
# 2011-01-07, Order Canceled: 111212
# 2011-01-07, SELL EXECUTED 111213
# 2011-01-07, Skipping trade due to stop loss distance being 0
# 2011-01-07, Volume calculation resulted in None.
# 2011-01-07, SELL EXECUTED 111214
# 2011-01-07, Updating trailing stop for SELL position to 83.33 order number 111215
# 2011-01-07, Order Canceled: 111215
# 2011-01-07, Order Canceled: 111216
# 2011-01-07, Updating trailing stop for SELL position to 83.32 order number 111217
# 2011-01-07, Order Canceled: 111217
# 2011-01-07, Updating trailing stop for SELL position to 83.28 order number 111218
# 2011-01-07, Order Canceled: 111218
# 2011-01-07, Updating trailing stop for SELL position to 83.24 order number 111219
# 2011-01-07, Order Canceled: 111219
# 2011-01-07, Updating trailing stop for SELL position to 83.2 order number 111220
# 2011-01-07, Order Canceled: 111220
# 2011-01-07, Updating trailing stop for SELL position to 83.18 order number 111221
# 2011-01-07, Order Canceled: 111221
# 2011-01-07, Updating trailing stop for SELL position to 83.15 order number 111222
# 2011-01-07, Order Canceled: 111222
# 2011-01-07, Updating trailing stop for SELL position to 83.13 order number 111223
# 2011-01-07, Order Canceled: 111223
# 2011-01-07, Updating trailing stop for SELL position to 83.09 order number 111224
# 2011-01-07, Order Canceled: 111224
# 2011-01-07, Updating trailing stop for SELL position to 83.07 order number 111225
# 2011-01-07, Order Canceled: 111225
# 2011-01-07, BUY EXECUTED 111226
# 2011-01-07, Skipping trade due to stop loss distance being 0
# 2011-01-07, Skipping trade due to stop loss distance being 0
# 2011-01-07, Volume calculation resulted in None.
# 2011-01-09, Skipping trade due to stop loss distance being 0
# 2011-01-09, Volume calculation resulted in None.
# 2011-01-10, BUY EXECUTED 111227
# 2011-01-10, Updating trailing stop for BUY position to 83.11 order number 111228
# 2011-01-10, Order Canceled: 111228
# 2011-01-10, Order Canceled: 111229
# 2011-01-10, Updating trailing stop for BUY position to 83.12 order number 111230
# 2011-01-10, Order Canceled: 111230
# 2011-01-10, Updating trailing stop for BUY position to 83.13 order number 111231
# 2011-01-10, Order Canceled: 111231
# 2011-01-10, Updating trailing stop for BUY position to 83.17 order number 111232
# 2011-01-10, Order Canceled: 111232
# 2011-01-10, SELL EXECUTED 111233
# 2011-01-10, Skipping trade due to stop loss distance being 0
# 2011-01-10, Volume calculation resulted in None.
# 2011-01-10, Skipping trade due to stop loss distance being 0
# 2011-01-10, Volume calculation resulted in None.
# 2011-01-10, SELL EXECUTED 111234
# 2011-01-10, Updating trailing stop for SELL position to 82.99 order number 111235
# 2011-01-10, Order Canceled: 111235
# 2011-01-10, Order Canceled: 111236
# 2011-01-10, Updating trailing stop for SELL position to 82.98 order number 111237
# 2011-01-10, Order Canceled: 111237
# 2011-01-10, Updating trailing stop for SELL position to 82.96 order number 111238
# 2011-01-10, Order Canceled: 111238
# 2011-01-10, Updating trailing stop for SELL position to 82.94 order number 111239
# 2011-01-10, Order Canceled: 111239
# 2011-01-10, Updating trailing stop for SELL position to 82.91 order number 111240
# 2011-01-10, Order Canceled: 111240
# 2011-01-10, Updating trailing stop for SELL position to 82.89 order number 111241
# 2011-01-10, Order Canceled: 111241
# 2011-01-10, Updating trailing stop for SELL position to 82.87 order number 111242
# 2011-01-10, Order Canceled: 111242
# 2011-01-10, Updating trailing stop for SELL position to 82.86 order number 111243
# 2011-01-10, Order Canceled: 111243
# 2011-01-10, Updating trailing stop for SELL position to 82.85 order number 111244
# 2011-01-10, Order Canceled: 111244
# 2011-01-10, Updating trailing stop for SELL position to 82.84 order number 111245
# 2011-01-10, Order Canceled: 111245
# 2011-01-10, Updating trailing stop for SELL position to 82.83 order number 111246
# 2011-01-10, Order Canceled: 111246
# 2011-01-10, Updating trailing stop for SELL position to 82.82 order number 111247
# 2011-01-10, Order Canceled: 111247
# 2011-01-10, Updating trailing stop for SELL position to 82.81 order number 111248
# 2011-01-10, Order Canceled: 111248
# 2011-01-10, BUY EXECUTED 111249
# 2011-01-10, Skipping trade due to stop loss distance being 0
# 2011-01-10, Volume calculation resulted in None.
# 2011-01-10, Skipping trade due to stop loss distance being 0
# 2011-01-10, Volume calculation resulted in None.
# 2011-01-10, BUY EXECUTED 111250
# 2011-01-10, SELL EXECUTED 111251
# 2011-01-10, TRADE CLOSED 111250 by 111251, Gross PnL=-10.56
# 2011-01-10, Order Canceled: 111252
# 2011-01-10, BUY EXECUTED 111253
# 2011-01-10, Updating trailing stop for BUY position to 82.88 order number 111254
# 2011-01-10, Order Canceled: 111254
# 2011-01-10, Order Canceled: 111255
# 2011-01-10, Updating trailing stop for BUY position to 82.89 order number 111256
# 2011-01-10, Order Canceled: 111256
# 2011-01-10, Updating trailing stop for BUY position to 82.9 order number 111257
# 2011-01-10, Order Canceled: 111257
# 2011-01-10, Updating trailing stop for BUY position to 82.91 order number 111258
# 2011-01-10, Order Canceled: 111258
# 2011-01-10, Updating trailing stop for BUY position to 82.94 order number 111259
# 2011-01-10, Order Canceled: 111259
# 2011-01-10, Updating trailing stop for BUY position to 82.99 order number 111260
# 2011-01-10, Order Canceled: 111260
# 2011-01-11, Updating trailing stop for BUY position to 83.0 order number 111261
# 2011-01-11, Order Canceled: 111261
# 2011-01-11, Updating trailing stop for BUY position to 83.02 order number 111262
# 2011-01-11, Order Canceled: 111262
# 2011-01-11, Updating trailing stop for BUY position to 83.04 order number 111263
# 2011-01-11, Order Canceled: 111263
# 2011-01-11, SELL EXECUTED 111264
# 2011-01-11, BUY EXECUTED 111265
# 2011-01-11, SELL EXECUTED 111266
# 2011-01-11, TRADE CLOSED 111265 by 111266, Gross PnL=-13.86
# 2011-01-11, Order Canceled: 111267
# 2011-01-11, BUY EXECUTED 111268
# 2011-01-11, SELL EXECUTED 111269
# 2011-01-11, TRADE CLOSED 111268 by 111269, Gross PnL=-10.71
# 2011-01-11, Order Canceled: 111270
# 2011-01-11, SELL EXECUTED 111271
# 2011-01-11, Updating trailing stop for SELL position to 83.25 order number 111272
# 2011-01-11, Order Canceled: 111272
# 2011-01-11, Order Canceled: 111273
# 2011-01-11, Updating trailing stop for SELL position to 83.24 order number 111274
# 2011-01-11, Order Canceled: 111274
# 2011-01-11, Updating trailing stop for SELL position to 83.23 order number 111275
# 2011-01-11, Order Canceled: 111275
# 2011-01-11, Updating trailing stop for SELL position to 83.22 order number 111276
# 2011-01-11, Order Canceled: 111276
# 2011-01-11, Updating trailing stop for SELL position to 83.21 order number 111277
# 2011-01-11, Order Canceled: 111277
# 2011-01-11, Updating trailing stop for SELL position to 83.19 order number 111278
# 2011-01-11, Order Canceled: 111278
# 2011-01-11, Updating trailing stop for SELL position to 83.17 order number 111279
# 2011-01-11, Order Canceled: 111279
# 2011-01-11, Updating trailing stop for SELL position to 83.16 order number 111280
# 2011-01-11, Order Canceled: 111280
# 2011-01-12, Updating trailing stop for SELL position to 83.15 order number 111281
# 2011-01-12, Order Canceled: 111281
# 2011-01-12, Updating trailing stop for SELL position to 83.14 order number 111282
# 2011-01-12, Order Canceled: 111282
# 2011-01-12, Updating trailing stop for SELL position to 83.13 order number 111283
# 2011-01-12, Order Canceled: 111283
# 2011-01-12, Updating trailing stop for SELL position to 83.12 order number 111284
# 2011-01-12, Order Canceled: 111284
# 2011-01-12, Updating trailing stop for SELL position to 83.09 order number 111285
# 2011-01-12, Order Canceled: 111285
# 2011-01-12, Updating trailing stop for SELL position to 83.08 order number 111286
# 2011-01-12, Order Canceled: 111286
# 2011-01-12, BUY EXECUTED 111287
# 2011-01-12, BUY EXECUTED 111288
# 2011-01-12, Updating trailing stop for BUY position to 83.27 order number 111289
# 2011-01-12, Order Canceled: 111289
# 2011-01-12, Order Canceled: 111290
# 2011-01-12, Updating trailing stop for BUY position to 83.29 order number 111291
# 2011-01-12, Order Canceled: 111291
# 2011-01-12, SELL EXECUTED 111292
# 2011-01-12, Skipping trade due to stop loss distance being 0
# 2011-01-12, Skipping trade due to stop loss distance being 0
# 2011-01-12, Volume calculation resulted in None.
# 2011-01-12, SELL EXECUTED 111293
# 2011-01-12, Updating trailing stop for SELL position to 83.31 order number 111294
# 2011-01-12, Order Canceled: 111294
# 2011-01-12, Order Canceled: 111295
# 2011-01-12, Updating trailing stop for SELL position to 83.29 order number 111296
# 2011-01-12, Order Canceled: 111296
# 2011-01-12, Updating trailing stop for SELL position to 83.26 order number 111297
# 2011-01-12, Order Canceled: 111297
# 2011-01-12, Updating trailing stop for SELL position to 83.25 order number 111298
# 2011-01-12, Order Canceled: 111298
# 2011-01-12, Updating trailing stop for SELL position to 83.22 order number 111299
# 2011-01-12, Order Canceled: 111299
# 2011-01-12, Updating trailing stop for SELL position to 83.21 order number 111300
# 2011-01-12, Order Canceled: 111300
# 2011-01-12, Updating trailing stop for SELL position to 83.19 order number 111301
# 2011-01-12, Order Canceled: 111301
# 2011-01-12, Updating trailing stop for SELL position to 83.17 order number 111302
# 2011-01-12, Order Canceled: 111302
# 2011-01-12, Updating trailing stop for SELL position to 83.13 order number 111303
# 2011-01-12, Order Canceled: 111303
# 2011-01-12, Updating trailing stop for SELL position to 83.1 order number 111304
# 2011-01-12, Order Canceled: 111304
# 2011-01-12, Updating trailing stop for SELL position to 83.06 order number 111305
# 2011-01-12, Order Canceled: 111305
# 2011-01-12, Updating trailing stop for SELL position to 83.01 order number 111306
# 2011-01-12, Order Canceled: 111306
# 2011-01-12, BUY EXECUTED 111307
# 2011-01-12, SELL EXECUTED 111308
# 2011-01-12, BUY EXECUTED 111309
# 2011-01-12, TRADE CLOSED 111308 by 111309, Gross PnL=-14.35
# 2011-01-12, Order Canceled: 111310
# 2011-01-12, BUY EXECUTED 111311
# 2011-01-12, Updating trailing stop for BUY position to 83.04 order number 111312
# 2011-01-12, Order Canceled: 111312
# 2011-01-12, Order Canceled: 111313
# 2011-01-12, SELL EXECUTED 111314
# 2011-01-12, Skipping trade due to stop loss distance being 0
# 2011-01-12, Skipping trade due to stop loss distance being 0
# 2011-01-12, Volume calculation resulted in None.
# 2011-01-13, SELL EXECUTED 111315
# 2011-01-13, BUY EXECUTED 111316
# 2011-01-13, TRADE CLOSED 111315 by 111316, Gross PnL=-11.48
# 2011-01-13, Order Canceled: 111317
# 2011-01-13, BUY EXECUTED 111318
# 2011-01-13, Updating trailing stop for BUY position to 82.69 order number 111319
# 2011-01-13, Order Canceled: 111319
# 2011-01-13, Order Canceled: 111320
# 2011-01-13, Updating trailing stop for BUY position to 82.7 order number 111321
# 2011-01-13, Order Canceled: 111321
# 2011-01-13, Updating trailing stop for BUY position to 82.72 order number 111322
# 2011-01-13, Order Canceled: 111322
# 2011-01-13, SELL EXECUTED 111323
# 2011-01-13, Skipping trade due to stop loss distance being 0
# 2011-01-13, Volume calculation resulted in None.
# 2011-01-13, SELL EXECUTED 111324
# 2011-01-13, Updating trailing stop for SELL position to 82.75 order number 111325
# 2011-01-13, Order Canceled: 111325
# 2011-01-13, Order Canceled: 111326
# 2011-01-13, Updating trailing stop for SELL position to 82.74 order number 111327
# 2011-01-13, Order Canceled: 111327
# 2011-01-13, Updating trailing stop for SELL position to 82.73 order number 111328
# 2011-01-13, Order Canceled: 111328
# 2011-01-13, Updating trailing stop for SELL position to 82.72 order number 111329
# 2011-01-13, Order Canceled: 111329
# 2011-01-13, Updating trailing stop for SELL position to 82.71 order number 111330
# 2011-01-13, Order Canceled: 111330
# 2011-01-13, Updating trailing stop for SELL position to 82.7 order number 111331
# 2011-01-13, Order Canceled: 111331
# 2011-01-13, Updating trailing stop for SELL position to 82.68 order number 111332
# 2011-01-13, Order Canceled: 111332
# 2011-01-13, Updating trailing stop for SELL position to 82.66 order number 111333
# 2011-01-13, Order Canceled: 111333
# 2011-01-13, Updating trailing stop for SELL position to 82.65 order number 111334
# 2011-01-13, Order Canceled: 111334
# 2011-01-13, Updating trailing stop for SELL position to 82.64 order number 111335
# 2011-01-13, Order Canceled: 111335
# 2011-01-14, Updating trailing stop for SELL position to 82.63 order number 111336
# 2011-01-14, Order Canceled: 111336
# 2011-01-14, Updating trailing stop for SELL position to 82.62 order number 111337
# 2011-01-14, Order Canceled: 111337
# 2011-01-14, Updating trailing stop for SELL position to 82.61 order number 111338
# 2011-01-14, Order Canceled: 111338
# 2011-01-14, Updating trailing stop for SELL position to 82.58 order number 111339
# 2011-01-14, Order Canceled: 111339
# 2011-01-14, BUY EXECUTED 111340
# 2011-01-14, Skipping trade due to stop loss distance being 0
# 2011-01-14, Skipping trade due to stop loss distance being 0
# 2011-01-14, Volume calculation resulted in None.
# 2011-01-14, BUY EXECUTED 111341
# 2011-01-14, Updating trailing stop for BUY position to 82.77 order number 111342
# 2011-01-14, Order Canceled: 111342
# 2011-01-14, Order Canceled: 111343
# 2011-01-14, Updating trailing stop for BUY position to 82.78 order number 111344
# 2011-01-14, Order Canceled: 111344
# 2011-01-14, Updating trailing stop for BUY position to 82.81 order number 111345
# 2011-01-14, Order Canceled: 111345
# 2011-01-14, SELL EXECUTED 111346
# 2011-01-14, Skipping trade due to stop loss distance being 0
# 2011-01-14, Volume calculation resulted in None.
# 2011-01-14, Skipping trade due to stop loss distance being 0
# 2011-01-14, Volume calculation resulted in None.
# 2011-01-14, Skipping trade due to stop loss distance being 0
# 2011-01-14, Volume calculation resulted in None.
# 2011-01-16, BUY EXECUTED 111347
# 2011-01-16, SELL EXECUTED 111348
# 2011-01-16, TRADE CLOSED 111347 by 111348, Gross PnL=-10.98
# 2011-01-16, Order Canceled: 111349
# 2011-01-16, SELL EXECUTED 111350
# 2011-01-16, Updating trailing stop for SELL position to 82.94 order number 111351
# 2011-01-16, Order Canceled: 111351
# 2011-01-16, Order Canceled: 111352
# 2011-01-16, Updating trailing stop for SELL position to 82.93 order number 111353
# 2011-01-16, Order Canceled: 111353
# 2011-01-16, Updating trailing stop for SELL position to 82.91 order number 111354
# 2011-01-16, Order Canceled: 111354
# 2011-01-17, BUY EXECUTED 111355
# 2011-01-17, Skipping trade due to stop loss distance being 0
# 2011-01-17, Volume calculation resulted in None.
# 2011-01-17, Skipping trade due to stop loss distance being 0
# 2011-01-17, Volume calculation resulted in None.
# 2011-01-17, Skipping trade due to stop loss distance being 0
# 2011-01-17, Volume calculation resulted in None.
# 2011-01-17, SELL EXECUTED 111356
# 2011-01-17, Updating trailing stop for SELL position to 82.56 order number 111357
# 2011-01-17, Order Canceled: 111357
# 2011-01-17, Order Canceled: 111358
# 2011-01-17, Updating trailing stop for SELL position to 82.55 order number 111359
# 2011-01-17, Order Canceled: 111359
# 2011-01-17, BUY EXECUTED 111360
# 2011-01-17, BUY EXECUTED 111361
# 2011-01-17, SELL EXECUTED 111362
# 2011-01-17, TRADE CLOSED 111361 by 111362, Gross PnL=-8.10
# 2011-01-17, Order Canceled: 111363
# 2011-01-17, BUY EXECUTED 111364
# 2011-01-17, SELL EXECUTED 111365
# 2011-01-17, TRADE CLOSED 111364 by 111365, Gross PnL=-6.06
# 2011-01-17, Order Canceled: 111366
# 2011-01-17, Skipping trade due to stop loss distance being 0
# 2011-01-17, Volume calculation resulted in None.
# 2011-01-17, SELL EXECUTED 111367
# 2011-01-17, Updating trailing stop for SELL position to 82.59 order number 111368
# 2011-01-17, Order Canceled: 111368
# 2011-01-17, Order Canceled: 111369
# 2011-01-17, Updating trailing stop for SELL position to 82.57 order number 111370
# 2011-01-17, Order Canceled: 111370
# 2011-01-18, Updating trailing stop for SELL position to 82.56 order number 111371
# 2011-01-18, Order Canceled: 111371
# 2011-01-18, BUY EXECUTED 111372
# 2011-01-18, Skipping trade due to stop loss distance being 0
# 2011-01-18, Volume calculation resulted in None.
# 2011-01-18, Skipping trade due to stop loss distance being 0
# 2011-01-18, Volume calculation resulted in None.
# 2011-01-18, BUY EXECUTED 111373
# 2011-01-18, Updating trailing stop for BUY position to 82.59 order number 111374
# 2011-01-18, Order Canceled: 111374
# 2011-01-18, Order Canceled: 111375
# 2011-01-18, SELL EXECUTED 111376
# 2011-01-18, SELL EXECUTED 111377
# 2011-01-18, Updating trailing stop for SELL position to 82.28 order number 111378
# 2011-01-18, Order Canceled: 111378
# 2011-01-18, Order Canceled: 111379
# 2011-01-18, Updating trailing stop for SELL position to 82.27 order number 111380
# 2011-01-19, Order Canceled: 111380
# 2011-01-19, BUY EXECUTED 111381
# 2011-01-19, BUY EXECUTED 111382
# 2011-01-19, Updating trailing stop for BUY position to 82.03 order number 111383
# 2011-01-19, Order Canceled: 111383
# 2011-01-19, Order Canceled: 111384
# 2011-01-19, Updating trailing stop for BUY position to 82.05 order number 111385
# 2011-01-19, Order Canceled: 111385
# 2011-01-19, Updating trailing stop for BUY position to 82.06 order number 111386
# 2011-01-19, Order Canceled: 111386
# 2011-01-19, Updating trailing stop for BUY position to 82.09 order number 111387
# 2011-01-19, Order Canceled: 111387
# 2011-01-19, Updating trailing stop for BUY position to 82.1 order number 111388
# 2011-01-19, Order Canceled: 111388
# 2011-01-19, Updating trailing stop for BUY position to 82.11 order number 111389
# 2011-01-19, Order Canceled: 111389
# 2011-01-19, SELL EXECUTED 111390
# 2011-01-19, BUY EXECUTED 111391
# 2011-01-19, Updating trailing stop for BUY position to 82.13 order number 111392
# 2011-01-19, Order Canceled: 111392
# 2011-01-19, Order Canceled: 111393
# 2011-01-19, Updating trailing stop for BUY position to 82.14 order number 111394
# 2011-01-19, Order Canceled: 111394
# 2011-01-19, SELL EXECUTED 111395
# 2011-01-20, Skipping trade due to stop loss distance being 0
# 2011-01-20, Volume calculation resulted in None.
# 2011-01-20, BUY EXECUTED 111396
# 2011-01-20, Updating trailing stop for BUY position to 82.71 order number 111397
# 2011-01-20, Order Canceled: 111397
# 2011-01-20, Order Canceled: 111398
# 2011-01-20, Updating trailing stop for BUY position to 82.74 order number 111399
# 2011-01-20, Order Canceled: 111399
# 2011-01-20, Updating trailing stop for BUY position to 82.78 order number 111400
# 2011-01-20, Order Canceled: 111400
# 2011-01-20, Updating trailing stop for BUY position to 82.8 order number 111401
# 2011-01-20, Order Canceled: 111401
# 2011-01-20, Updating trailing stop for BUY position to 82.82 order number 111402
# 2011-01-20, Order Canceled: 111402
# 2011-01-20, Updating trailing stop for BUY position to 82.84 order number 111403
# 2011-01-20, Order Canceled: 111403
# 2011-01-20, Updating trailing stop for BUY position to 82.85 order number 111404
# 2011-01-20, Order Canceled: 111404
# 2011-01-20, Updating trailing stop for BUY position to 82.86 order number 111405
# 2011-01-20, Order Canceled: 111405
# 2011-01-20, SELL EXECUTED 111406
# 2011-01-21, SELL EXECUTED 111407
# 2011-01-21, Updating trailing stop for SELL position to 82.96 order number 111408
# 2011-01-21, Order Canceled: 111408
# 2011-01-21, Order Canceled: 111409
# 2011-01-21, Updating trailing stop for SELL position to 82.91 order number 111410
# 2011-01-21, Order Canceled: 111410
# 2011-01-21, Updating trailing stop for SELL position to 82.9 order number 111411
# 2011-01-21, Order Canceled: 111411
# 2011-01-21, Updating trailing stop for SELL position to 82.89 order number 111412
# 2011-01-21, Order Canceled: 111412
# 2011-01-21, Updating trailing stop for SELL position to 82.87 order number 111413
# 2011-01-21, Order Canceled: 111413
# 2011-01-21, Updating trailing stop for SELL position to 82.86 order number 111414
# 2011-01-21, Order Canceled: 111414
# 2011-01-21, BUY EXECUTED 111415
# 2011-01-21, SELL EXECUTED 111416
# 2011-01-21, Updating trailing stop for SELL position to 82.82 order number 111417
# 2011-01-21, Order Canceled: 111417
# 2011-01-21, Order Canceled: 111418
# 2011-01-21, Updating trailing stop for SELL position to 82.8 order number 111419
# 2011-01-21, Order Canceled: 111419
# 2011-01-21, Updating trailing stop for SELL position to 82.79 order number 111420
# 2011-01-21, Order Canceled: 111420
# 2011-01-21, Updating trailing stop for SELL position to 82.78 order number 111421
# 2011-01-21, Order Canceled: 111421
# 2011-01-21, Updating trailing stop for SELL position to 82.7 order number 111422
# 2011-01-21, Order Canceled: 111422
# 2011-01-21, Updating trailing stop for SELL position to 82.69 order number 111423
# 2011-01-21, Order Canceled: 111423
# 2011-01-21, BUY EXECUTED 111424
# 2011-01-23, BUY EXECUTED 111425
# 2011-01-23, SELL EXECUTED 111426
# 2011-01-23, TRADE CLOSED 111425 by 111426, Gross PnL=-15.10
# 2011-01-23, Order Canceled: 111427
# 2011-01-23, BUY EXECUTED 111428
# 2011-01-23, Updating trailing stop for BUY position to 82.63 order number 111429
# 2011-01-23, Order Canceled: 111429
# 2011-01-23, Order Canceled: 111430
# 2011-01-23, Updating trailing stop for BUY position to 82.65 order number 111431
# 2011-01-23, Order Canceled: 111431
# 2011-01-23, Updating trailing stop for BUY position to 82.67 order number 111432
# 2011-01-23, Order Canceled: 111432
# 2011-01-23, Updating trailing stop for BUY position to 82.7 order number 111433
# 2011-01-23, Order Canceled: 111433
# 2011-01-24, SELL EXECUTED 111434
# 2011-01-24, BUY EXECUTED 111435
# 2011-01-24, Updating trailing stop for BUY position to 82.73 order number 111436
# 2011-01-24, Order Canceled: 111436
# 2011-01-24, Order Canceled: 111437
# 2011-01-24, Updating trailing stop for BUY position to 82.74 order number 111438
# 2011-01-24, Order Canceled: 111438
# 2011-01-24, Updating trailing stop for BUY position to 82.75 order number 111439
# 2011-01-24, Order Canceled: 111439
# 2011-01-24, Updating trailing stop for BUY position to 82.78 order number 111440
# 2011-01-24, Order Canceled: 111440
# 2011-01-24, Updating trailing stop for BUY position to 82.79 order number 111441
# 2011-01-24, Order Canceled: 111441
# 2011-01-24, SELL EXECUTED 111442
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Volume calculation resulted in None.
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Volume calculation resulted in None.
# 2011-01-24, SELL EXECUTED 111443
# 2011-01-24, Updating trailing stop for SELL position to 82.67 order number 111444
# 2011-01-24, Order Canceled: 111444
# 2011-01-24, Order Canceled: 111445
# 2011-01-24, Updating trailing stop for SELL position to 82.62 order number 111446
# 2011-01-24, Order Canceled: 111446
# 2011-01-24, Updating trailing stop for SELL position to 82.61 order number 111447
# 2011-01-24, Order Canceled: 111447
# 2011-01-24, Updating trailing stop for SELL position to 82.6 order number 111448
# 2011-01-24, Order Canceled: 111448
# 2011-01-24, Updating trailing stop for SELL position to 82.54 order number 111449
# 2011-01-24, Order Canceled: 111449
# 2011-01-24, Updating trailing stop for SELL position to 82.53 order number 111450
# 2011-01-24, Order Canceled: 111450
# 2011-01-24, Updating trailing stop for SELL position to 82.51 order number 111451
# 2011-01-24, Order Canceled: 111451
# 2011-01-24, Updating trailing stop for SELL position to 82.48 order number 111452
# 2011-01-24, Order Canceled: 111452
# 2011-01-24, BUY EXECUTED 111453
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Volume calculation resulted in None.
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Volume calculation resulted in None.
# 2011-01-24, BUY EXECUTED 111454
# 2011-01-24, Updating trailing stop for BUY position to 82.49 order number 111455
# 2011-01-24, Order Canceled: 111455
# 2011-01-24, Order Canceled: 111456
# 2011-01-24, SELL EXECUTED 111457
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Volume calculation resulted in None.
# 2011-01-24, Skipping trade due to stop loss distance being 0
# 2011-01-24, Volume calculation resulted in None.
# 2011-01-25, Skipping trade due to stop loss distance being 0
# 2011-01-25, Volume calculation resulted in None.
# 2011-01-25, SELL EXECUTED 111458
# 2011-01-25, Updating trailing stop for SELL position to 82.45 order number 111459
# 2011-01-25, Order Canceled: 111459
# 2011-01-25, Order Canceled: 111460
# 2011-01-25, BUY EXECUTED 111461
# 2011-01-25, Skipping trade due to stop loss distance being 0
# 2011-01-25, Volume calculation resulted in None.
# 2011-01-25, SELL EXECUTED 111462
# 2011-01-25, Updating trailing stop for SELL position to 82.5 order number 111463
# 2011-01-25, Order Canceled: 111463
# 2011-01-25, Order Canceled: 111464
# 2011-01-25, Updating trailing stop for SELL position to 82.48 order number 111465
# 2011-01-25, Order Canceled: 111465
# 2011-01-25, Updating trailing stop for SELL position to 82.47 order number 111466
# 2011-01-25, Order Canceled: 111466
# 2011-01-25, Updating trailing stop for SELL position to 82.45 order number 111467
# 2011-01-25, Order Canceled: 111467
# 2011-01-25, Updating trailing stop for SELL position to 82.39 order number 111468
# 2011-01-25, Order Canceled: 111468
# 2011-01-25, Updating trailing stop for SELL position to 82.33 order number 111469
# 2011-01-25, Order Canceled: 111469
# 2011-01-25, Updating trailing stop for SELL position to 82.31 order number 111470
# 2011-01-25, Order Canceled: 111470
# 2011-01-25, Updating trailing stop for SELL position to 82.3 order number 111471
# 2011-01-25, Order Canceled: 111471
# 2011-01-25, Updating trailing stop for SELL position to 82.27 order number 111472
# 2011-01-25, Order Canceled: 111472
# 2011-01-25, Updating trailing stop for SELL position to 82.26 order number 111473
# 2011-01-25, Order Canceled: 111473
# 2011-01-25, Updating trailing stop for SELL position to 82.23 order number 111474
# 2011-01-25, Order Canceled: 111474
# 2011-01-25, Updating trailing stop for SELL position to 82.17 order number 111475
# 2011-01-25, Order Canceled: 111475
# 2011-01-25, BUY EXECUTED 111476
# 2011-01-25, BUY EXECUTED 111477
# 2011-01-25, Updating trailing stop for BUY position to 82.19 order number 111478
# 2011-01-25, Order Canceled: 111478
# 2011-01-25, Order Canceled: 111479
# 2011-01-25, SELL EXECUTED 111480
# 2011-01-25, Skipping trade due to stop loss distance being 0
# 2011-01-25, Volume calculation resulted in None.
# 2011-01-26, SELL EXECUTED 111481
# 2011-01-26, Updating trailing stop for SELL position to 82.06 order number 111482
# 2011-01-26, Order Canceled: 111482
# 2011-01-26, Order Canceled: 111483
# 2011-01-26, BUY EXECUTED 111484
# 2011-01-26, Skipping trade due to stop loss distance being 0
# 2011-01-26, Volume calculation resulted in None.
# 2011-01-26, Skipping trade due to stop loss distance being 0
# 2011-01-26, Volume calculation resulted in None.
# 2011-01-26, BUY EXECUTED 111485
# 2011-01-26, Updating trailing stop for BUY position to 82.08 order number 111486
# 2011-01-26, Order Canceled: 111486
# 2011-01-26, Order Canceled: 111487
# 2011-01-26, Updating trailing stop for BUY position to 82.11 order number 111488
# 2011-01-26, Order Canceled: 111488
# 2011-01-26, SELL EXECUTED 111489
# 2011-01-26, BUY EXECUTED 111490
# 2011-01-26, Updating trailing stop for BUY position to 82.22 order number 111491
# 2011-01-26, Order Canceled: 111491
# 2011-01-26, Order Canceled: 111492
# 2011-01-26, Updating trailing stop for BUY position to 82.24 order number 111493
# 2011-01-26, Order Canceled: 111493
# 2011-01-26, Updating trailing stop for BUY position to 82.27 order number 111494
# 2011-01-26, Order Canceled: 111494
# 2011-01-26, Updating trailing stop for BUY position to 82.28 order number 111495
# 2011-01-26, Order Canceled: 111495
# 2011-01-26, Updating trailing stop for BUY position to 82.29 order number 111496
# 2011-01-26, Order Canceled: 111496
# 2011-01-26, Updating trailing stop for BUY position to 82.32 order number 111497
# 2011-01-26, Order Canceled: 111497
# 2011-01-26, Updating trailing stop for BUY position to 82.33 order number 111498
# 2011-01-26, Order Canceled: 111498
# 2011-01-26, Updating trailing stop for BUY position to 82.34 order number 111499
# 2011-01-26, Order Canceled: 111499
# 2011-01-26, Updating trailing stop for BUY position to 82.35 order number 111500
# 2011-01-26, Order Canceled: 111500
# 2011-01-26, Updating trailing stop for BUY position to 82.38 order number 111501
# 2011-01-26, Order Canceled: 111501
# 2011-01-26, SELL EXECUTED 111502
# 2011-01-27, Skipping trade due to stop loss distance being 0
# 2011-01-27, Volume calculation resulted in None.
# 2011-01-27, BUY EXECUTED 111503
# 2011-01-27, Updating trailing stop for BUY position to 82.79 order number 111504
# 2011-01-27, Order Canceled: 111504
# 2011-01-27, Order Canceled: 111505
# 2011-01-27, Updating trailing stop for BUY position to 82.8 order number 111506
# 2011-01-27, Order Canceled: 111506
# 2011-01-27, Updating trailing stop for BUY position to 82.84 order number 111507
# 2011-01-27, Order Canceled: 111507
# 2011-01-27, Updating trailing stop for BUY position to 82.85 order number 111508
# 2011-01-27, Order Canceled: 111508
# 2011-01-27, Updating trailing stop for BUY position to 82.87 order number 111509
# 2011-01-27, Order Canceled: 111509
# 2011-01-27, SELL EXECUTED 111510
# 2011-01-28, Skipping trade due to stop loss distance being 0
# 2011-01-28, Volume calculation resulted in None.
# 2011-01-28, Skipping trade due to stop loss distance being 0
# 2011-01-28, Volume calculation resulted in None.
# 2011-01-30, Skipping trade due to stop loss distance being 0
# 2011-01-30, Volume calculation resulted in None.
# 2011-01-30, SELL EXECUTED 111511
# 2011-01-30, Updating trailing stop for SELL position to 82.09 order number 111512
# 2011-01-30, Order Canceled: 111512
# 2011-01-30, Order Canceled: 111513
# 2011-01-30, Updating trailing stop for SELL position to 82.08 order number 111514
# 2011-01-30, Order Canceled: 111514
# 2011-01-31, Updating trailing stop for SELL position to 82.07 order number 111515
# 2011-01-31, Order Canceled: 111515
# 2011-01-31, Updating trailing stop for SELL position to 82.06 order number 111516
# 2011-01-31, Order Canceled: 111516
# 2011-01-31, Updating trailing stop for SELL position to 82.03 order number 111517
# 2011-01-31, Order Canceled: 111517
# 2011-01-31, BUY EXECUTED 111518
# 2011-01-31, BUY EXECUTED 111519
# 2011-01-31, Updating trailing stop for BUY position to 82.11 order number 111520
# 2011-01-31, Order Canceled: 111520
# 2011-01-31, Order Canceled: 111521
# 2011-01-31, Updating trailing stop for BUY position to 82.12 order number 111522
# 2011-01-31, Order Canceled: 111522
# 2011-01-31, Updating trailing stop for BUY position to 82.14 order number 111523
# 2011-01-31, Order Canceled: 111523
# 2011-01-31, SELL EXECUTED 111524
# 2011-01-31, BUY EXECUTED 111525
# 2011-01-31, SELL EXECUTED 111526
# 2011-01-31, Skipping trade due to stop loss distance being 0
# 2011-01-31, TRADE CLOSED 111525 by 111526, Gross PnL=-14.40
# 2011-01-31, Order Canceled: 111527
# 2011-01-31, Skipping trade due to stop loss distance being 0
# 2011-01-31, Volume calculation resulted in None.
# 2011-01-31, Skipping trade due to stop loss distance being 0
# 2011-01-31, Volume calculation resulted in None.
# 2011-01-31, SELL EXECUTED 111528
# 2011-01-31, Updating trailing stop for SELL position to 81.99 order number 111529
# 2011-01-31, Order Canceled: 111529
# 2011-01-31, Order Canceled: 111530
# 2011-01-31, Updating trailing stop for SELL position to 81.98 order number 111531
# 2011-02-01, Order Canceled: 111531
# 2011-02-01, Updating trailing stop for SELL position to 81.93 order number 111532
# 2011-02-01, Order Canceled: 111532
# 2011-02-01, Updating trailing stop for SELL position to 81.91 order number 111533
# 2011-02-01, Order Canceled: 111533
# 2011-02-01, Updating trailing stop for SELL position to 81.9 order number 111534
# 2011-02-01, Order Canceled: 111534
# 2011-02-01, BUY EXECUTED 111535
# 2011-02-01, Skipping trade due to stop loss distance being 0
# 2011-02-01, Volume calculation resulted in None.
# 2011-02-01, SELL EXECUTED 111536
# 2011-02-01, Updating trailing stop for SELL position to 81.63 order number 111537
# 2011-02-01, Order Canceled: 111537
# 2011-02-01, Order Canceled: 111538
# 2011-02-01, Updating trailing stop for SELL position to 81.6 order number 111539
# 2011-02-01, Order Canceled: 111539
# 2011-02-01, BUY EXECUTED 111540
# 2011-02-01, SELL EXECUTED 111541
# 2011-02-01, BUY EXECUTED 111542
# 2011-02-01, TRADE CLOSED 111541 by 111542, Gross PnL=-13.08
# 2011-02-01, Order Canceled: 111543
# 2011-02-01, BUY EXECUTED 111544
# 2011-02-01, SELL EXECUTED 111546
# 2011-02-01, TRADE CLOSED 111544 by 111546, Gross PnL=34.58
# 2011-02-01, Order Canceled: 111545
# 2011-02-01, Skipping trade due to stop loss distance being 0
# 2011-02-01, Volume calculation resulted in None.
# 2011-02-01, SELL EXECUTED 111547
# 2011-02-01, Updating trailing stop for SELL position to 81.5 order number 111548
# 2011-02-01, Order Canceled: 111548
# 2011-02-01, Order Canceled: 111549
# 2011-02-01, Updating trailing stop for SELL position to 81.49 order number 111550
# 2011-02-01, Order Canceled: 111550
# 2011-02-01, Updating trailing stop for SELL position to 81.47 order number 111551
# 2011-02-01, Order Canceled: 111551
# 2011-02-01, Updating trailing stop for SELL position to 81.46 order number 111552
# 2011-02-01, Order Canceled: 111552
# 2011-02-01, Updating trailing stop for SELL position to 81.45 order number 111553
# 2011-02-01, Order Canceled: 111553
# 2011-02-01, BUY EXECUTED 111554
# 2011-02-01, BUY EXECUTED 111555
# 2011-02-01, Updating trailing stop for BUY position to 81.36 order number 111556
# 2011-02-01, Order Canceled: 111556
# 2011-02-01, Order Canceled: 111557
# 2011-02-01, Updating trailing stop for BUY position to 81.38 order number 111558
# 2011-02-01, Order Canceled: 111558
# 2011-02-01, Updating trailing stop for BUY position to 81.4 order number 111559
# 2011-02-01, Order Canceled: 111559
# 2011-02-01, Updating trailing stop for BUY position to 81.41 order number 111560
# 2011-02-01, Order Canceled: 111560
# 2011-02-01, Updating trailing stop for BUY position to 81.43 order number 111561
# 2011-02-01, Order Canceled: 111561
# 2011-02-01, Updating trailing stop for BUY position to 81.47 order number 111562
# 2011-02-01, Order Canceled: 111562
# 2011-02-01, Updating trailing stop for BUY position to 81.48 order number 111563
# 2011-02-01, Order Canceled: 111563
# 2011-02-01, SELL EXECUTED 111564
# 2011-02-01, SELL EXECUTED 111565
# 2011-02-01, Updating trailing stop for SELL position to 81.52 order number 111566
# 2011-02-01, Order Canceled: 111566
# 2011-02-01, Order Canceled: 111567
# 2011-02-01, Updating trailing stop for SELL position to 81.51 order number 111568
# 2011-02-01, Order Canceled: 111568
# ...
# 2011-12-20, BUY EXECUTED 116567
# 2011-12-20, SELL EXECUTED 116568
# 2011-12-20, Updating trailing stop for SELL position to 77.81 order number 116569
# 2011-12-20, Order Canceled: 116569
# 2011-12-20, Order Canceled: 116570
# 2011-12-20, Updating trailing stop for SELL position to 77.8 order number 116571
# 2011-12-20, Order Canceled: 116571
# 2011-12-20, Updating trailing stop for SELL position to 77.79 order number 116572
# 2011-12-20, Order Canceled: 116572
# 2011-12-20, BUY EXECUTED 116573
# 2011-12-20, BUY EXECUTED 116574
# 2011-12-20, Updating trailing stop for BUY position to 77.84 order number 116575
# 2011-12-20, Order Canceled: 116575
# 2011-12-20, Order Canceled: 116576
# 2011-12-20, SELL EXECUTED 116577
# 2011-12-20, SELL EXECUTED 116578
# 2011-12-20, BUY EXECUTED 116579
# 2011-12-20, TRADE CLOSED 116578 by 116579, Gross PnL=-12.28
# 2011-12-20, Order Canceled: 116580
# 2011-12-20, SELL EXECUTED 116581
# 2011-12-20, Updating trailing stop for SELL position to 77.82 order number 116582
# 2011-12-20, Order Canceled: 116582
# 2011-12-20, Order Canceled: 116583
# 2011-12-20, Updating trailing stop for SELL position to 77.81 order number 116584
# 2011-12-20, Order Canceled: 116584
# 2011-12-21, BUY EXECUTED 116585
# 2011-12-21, BUY EXECUTED 116586
# 2011-12-21, Updating trailing stop for BUY position to 77.83 order number 116587
# 2011-12-21, Order Canceled: 116587
# 2011-12-21, Order Canceled: 116588
# 2011-12-21, Updating trailing stop for BUY position to 77.84 order number 116589
# 2011-12-21, Order Canceled: 116589
# 2011-12-21, Updating trailing stop for BUY position to 77.87 order number 116590
# 2011-12-21, Order Canceled: 116590
# 2011-12-21, Updating trailing stop for BUY position to 77.88 order number 116591
# 2011-12-21, Order Canceled: 116591
# 2011-12-21, Updating trailing stop for BUY position to 77.89 order number 116592
# 2011-12-21, Order Canceled: 116592
# 2011-12-21, Updating trailing stop for BUY position to 77.91 order number 116593
# 2011-12-21, Order Canceled: 116593
# 2011-12-21, Updating trailing stop for BUY position to 77.92 order number 116594
# 2011-12-21, Order Canceled: 116594
# 2011-12-21, Updating trailing stop for BUY position to 77.93 order number 116595
# 2011-12-21, Order Canceled: 116595
# 2011-12-21, Updating trailing stop for BUY position to 77.94 order number 116596
# 2011-12-21, Order Canceled: 116596
# 2011-12-21, SELL EXECUTED 116597
# 2011-12-21, SELL EXECUTED 116598
# 2011-12-21, BUY EXECUTED 116599
# 2011-12-21, TRADE CLOSED 116598 by 116599, Gross PnL=-11.86
# 2011-12-21, Order Canceled: 116600
# 2011-12-21, BUY EXECUTED 116601
# 2011-12-21, Updating trailing stop for BUY position to 78.04 order number 116602
# 2011-12-21, Order Canceled: 116602
# 2011-12-21, Order Canceled: 116603
# 2011-12-21, Updating trailing stop for BUY position to 78.05 order number 116604
# 2011-12-21, Order Canceled: 116604
# 2011-12-21, SELL EXECUTED 116605
# 2011-12-21, BUY EXECUTED 116606
# 2011-12-21, Updating trailing stop for BUY position to 78.05 order number 116607
# 2011-12-21, Order Canceled: 116607
# 2011-12-21, Order Canceled: 116608
# 2011-12-21, SELL EXECUTED 116609
# 2011-12-22, BUY EXECUTED 116610
# 2011-12-22, SELL EXECUTED 116611
# 2011-12-22, TRADE CLOSED 116610 by 116611, Gross PnL=-11.45
# 2011-12-22, Order Canceled: 116612
# 2011-12-22, BUY EXECUTED 116613
# 2011-12-22, Updating trailing stop for BUY position to 78.14 order number 116614
# 2011-12-22, Order Canceled: 116614
# 2011-12-22, Order Canceled: 116615
# 2011-12-22, SELL EXECUTED 116616
# 2011-12-22, SELL EXECUTED 116617
# 2011-12-22, BUY EXECUTED 116618
# 2011-12-22, TRADE CLOSED 116617 by 116618, Gross PnL=-12.19
# 2011-12-22, Order Canceled: 116619
# 2011-12-23, SELL EXECUTED 116620
# 2011-12-23, Updating trailing stop for SELL position to 78.09 order number 116621
# 2011-12-23, Order Canceled: 116621
# 2011-12-23, Order Canceled: 116622
# 2011-12-23, Updating trailing stop for SELL position to 78.08 order number 116623
# 2011-12-23, Order Canceled: 116623
# 2011-12-23, Updating trailing stop for SELL position to 78.07 order number 116624
# 2011-12-23, Order Canceled: 116624
# 2011-12-23, Updating trailing stop for SELL position to 78.06 order number 116625
# 2011-12-23, Order Canceled: 116625
# 2011-12-23, Updating trailing stop for SELL position to 78.01 order number 116626
# 2011-12-23, Order Canceled: 116626
# 2011-12-23, BUY EXECUTED 116627
# 2011-12-23, BUY EXECUTED 116628
# 2011-12-23, Updating trailing stop for BUY position to 78.06 order number 116629
# 2011-12-23, Order Canceled: 116629
# 2011-12-23, Order Canceled: 116630
# 2011-12-23, Updating trailing stop for BUY position to 78.07 order number 116631
# 2011-12-23, Order Canceled: 116631
# 2011-12-23, Updating trailing stop for BUY position to 78.08 order number 116632
# 2011-12-23, Order Canceled: 116632
# 2011-12-23, Updating trailing stop for BUY position to 78.09 order number 116633
# 2011-12-23, Order Canceled: 116633
# 2011-12-23, SELL EXECUTED 116634
# 2011-12-26, SELL EXECUTED 116635
# 2011-12-26, Updating trailing stop for SELL position to 78.0 order number 116636
# 2011-12-26, Order Canceled: 116636
# 2011-12-26, Order Canceled: 116637
# 2011-12-26, Updating trailing stop for SELL position to 77.97 order number 116638
# 2011-12-26, Order Canceled: 116638
# 2011-12-26, Updating trailing stop for SELL position to 77.94 order number 116639
# 2011-12-26, Order Canceled: 116639
# 2011-12-26, BUY EXECUTED 116640
# 2011-12-26, SELL EXECUTED 116641
# 2011-12-26, Updating trailing stop for SELL position to 77.95 order number 116642
# 2011-12-26, Order Canceled: 116642
# 2011-12-26, Order Canceled: 116643
# 2011-12-26, Updating trailing stop for SELL position to 77.94 order number 116644
# 2011-12-26, Order Canceled: 116644
# 2011-12-26, BUY EXECUTED 116645
# 2011-12-26, Skipping trade due to stop loss distance being 0
# 2011-12-26, Volume calculation resulted in None.
# 2011-12-26, BUY EXECUTED 116646
# 2011-12-26, Updating trailing stop for BUY position to 77.94 order number 116647
# 2011-12-26, Order Canceled: 116647
# 2011-12-26, Order Canceled: 116648
# 2011-12-26, Updating trailing stop for BUY position to 77.95 order number 116649
# 2011-12-26, Order Canceled: 116649
# 2011-12-26, Updating trailing stop for BUY position to 77.96 order number 116650
# 2011-12-26, Order Canceled: 116650
# 2011-12-26, Updating trailing stop for BUY position to 77.97 order number 116651
# 2011-12-26, Order Canceled: 116651
# 2011-12-26, SELL EXECUTED 116652
# 2011-12-27, SELL EXECUTED 116653
# 2011-12-27, Updating trailing stop for SELL position to 77.94 order number 116654
# 2011-12-27, Order Canceled: 116654
# 2011-12-27, Order Canceled: 116655
# 2011-12-27, Updating trailing stop for SELL position to 77.93 order number 116656
# 2011-12-27, Order Canceled: 116656
# 2011-12-27, Updating trailing stop for SELL position to 77.91 order number 116657
# 2011-12-27, Order Canceled: 116657
# 2011-12-27, BUY EXECUTED 116658
# 2011-12-27, SELL EXECUTED 116659
# 2011-12-27, Updating trailing stop for SELL position to 77.88 order number 116660
# 2011-12-27, Order Canceled: 116660
# 2011-12-27, Order Canceled: 116661
# 2011-12-27, Updating trailing stop for SELL position to 77.87 order number 116662
# 2011-12-27, Order Canceled: 116662
# 2011-12-27, Updating trailing stop for SELL position to 77.86 order number 116663
# 2011-12-27, Order Canceled: 116663
# 2011-12-27, BUY EXECUTED 116664
# 2011-12-27, BUY EXECUTED 116665
# 2011-12-27, Updating trailing stop for BUY position to 77.83 order number 116666
# 2011-12-27, Order Canceled: 116666
# 2011-12-27, Order Canceled: 116667
# 2011-12-27, Updating trailing stop for BUY position to 77.84 order number 116668
# 2011-12-27, Order Canceled: 116668
# 2011-12-27, SELL EXECUTED 116669
# 2011-12-27, BUY EXECUTED 116670
# 2011-12-27, SELL EXECUTED 116671
# 2011-12-27, TRADE CLOSED 116670 by 116671, Gross PnL=-3.97
# 2011-12-27, Order Canceled: 116672
# 2011-12-27, Skipping trade due to stop loss distance being 0
# 2011-12-27, Volume calculation resulted in None.
# 2011-12-27, BUY EXECUTED 116673
# 2011-12-27, SELL EXECUTED 116674
# 2011-12-27, TRADE CLOSED 116673 by 116674, Gross PnL=-12.56
# 2011-12-27, Order Canceled: 116675
# 2011-12-27, BUY EXECUTED 116676
# 2011-12-27, SELL EXECUTED 116677
# 2011-12-27, TRADE CLOSED 116676 by 116677, Gross PnL=-12.54
# 2011-12-27, Order Canceled: 116678
# 2011-12-27, SELL EXECUTED 116679
# 2011-12-27, Updating trailing stop for SELL position to 77.8 order number 116680
# 2011-12-27, Order Canceled: 116680
# 2011-12-27, Order Canceled: 116681
# 2011-12-28, Updating trailing stop for SELL position to 77.79 order number 116682
# 2011-12-28, Order Canceled: 116682
# 2011-12-28, BUY EXECUTED 116683
# 2011-12-28, SELL EXECUTED 116684
# 2011-12-28, Updating trailing stop for SELL position to 77.75 order number 116685
# 2011-12-28, Order Canceled: 116685
# 2011-12-28, Order Canceled: 116686
# 2011-12-28, Updating trailing stop for SELL position to 77.74 order number 116687
# 2011-12-28, Order Canceled: 116687
# 2011-12-28, Updating trailing stop for SELL position to 77.73 order number 116688
# 2011-12-28, Order Canceled: 116688
# 2011-12-28, Updating trailing stop for SELL position to 77.72 order number 116689
# 2011-12-28, Order Canceled: 116689
# 2011-12-28, Updating trailing stop for SELL position to 77.7 order number 116690
# 2011-12-28, Order Canceled: 116690
# 2011-12-28, Updating trailing stop for SELL position to 77.68 order number 116691
# 2011-12-28, Order Canceled: 116691
# 2011-12-28, BUY EXECUTED 116692
# 2011-12-28, SELL EXECUTED 116693
# 2011-12-28, Updating trailing stop for SELL position to 77.68 order number 116694
# 2011-12-28, Order Canceled: 116694
# 2011-12-28, Order Canceled: 116695
# 2011-12-28, Updating trailing stop for SELL position to 77.65 order number 116696
# 2011-12-28, Order Canceled: 116696
# 2011-12-28, Updating trailing stop for SELL position to 77.64 order number 116697
# 2011-12-28, Order Canceled: 116697
# 2011-12-28, Updating trailing stop for SELL position to 77.63 order number 116698
# 2011-12-28, Order Canceled: 116698
# 2011-12-28, BUY EXECUTED 116699
# 2011-12-28, SELL EXECUTED 116700
# 2011-12-28, Updating trailing stop for SELL position to 77.92 order number 116701
# 2011-12-28, Order Canceled: 116701
# 2011-12-28, Order Canceled: 116702
# 2011-12-28, BUY EXECUTED 116703
# 2011-12-28, SELL EXECUTED 116704
# 2011-12-28, Updating trailing stop for SELL position to 77.81 order number 116705
# 2011-12-28, Order Canceled: 116705
# 2011-12-28, Order Canceled: 116706
# 2011-12-28, Updating trailing stop for SELL position to 77.79 order number 116707
# 2011-12-29, Order Canceled: 116707
# 2011-12-29, Updating trailing stop for SELL position to 77.78 order number 116708
# 2011-12-29, Order Canceled: 116708
# 2011-12-29, Updating trailing stop for SELL position to 77.77 order number 116709
# 2011-12-29, Order Canceled: 116709
# 2011-12-29, Updating trailing stop for SELL position to 77.76 order number 116710
# 2011-12-29, Order Canceled: 116710
# 2011-12-29, Updating trailing stop for SELL position to 77.75 order number 116711
# 2011-12-29, Order Canceled: 116711
# 2011-12-29, BUY EXECUTED 116712
# 2011-12-29, SELL EXECUTED 116713
# 2011-12-29, Updating trailing stop for SELL position to 77.74 order number 116714
# 2011-12-29, Order Canceled: 116714
# 2011-12-29, Order Canceled: 116715
# 2011-12-29, Updating trailing stop for SELL position to 77.73 order number 116716
# 2011-12-29, Order Canceled: 116716
# 2011-12-29, BUY EXECUTED 116717
# 2011-12-29, BUY EXECUTED 116718
# 2011-12-29, Updating trailing stop for BUY position to 77.77 order number 116719
# 2011-12-29, Order Canceled: 116719
# 2011-12-29, Order Canceled: 116720
# 2011-12-29, SELL EXECUTED 116721
# 2011-12-29, SELL EXECUTED 116722
# 2011-12-29, Updating trailing stop for SELL position to 77.73 order number 116723
# 2011-12-29, Order Canceled: 116723
# 2011-12-29, Order Canceled: 116724
# 2011-12-29, Updating trailing stop for SELL position to 77.72 order number 116725
# 2011-12-29, Order Canceled: 116725
# 2011-12-29, Updating trailing stop for SELL position to 77.71 order number 116726
# 2011-12-29, Order Canceled: 116726
# 2011-12-29, Updating trailing stop for SELL position to 77.7 order number 116727
# 2011-12-29, Order Canceled: 116727
# 2011-12-29, Updating trailing stop for SELL position to 77.69 order number 116728
# 2011-12-29, Order Canceled: 116728
# 2011-12-29, Updating trailing stop for SELL position to 77.68 order number 116729
# 2011-12-29, Order Canceled: 116729
# 2011-12-29, Updating trailing stop for SELL position to 77.67 order number 116730
# 2011-12-29, Order Canceled: 116730
# 2011-12-29, Updating trailing stop for SELL position to 77.66 order number 116731
# 2011-12-29, Order Canceled: 116731
# 2011-12-29, BUY EXECUTED 116732
# 2011-12-29, BUY EXECUTED 116733
# 2011-12-29, Updating trailing stop for BUY position to 77.64 order number 116734
# 2011-12-29, Order Canceled: 116734
# 2011-12-29, Order Canceled: 116735
# 2011-12-29, Updating trailing stop for BUY position to 77.66 order number 116736
# 2011-12-29, Order Canceled: 116736
# 2011-12-29, SELL EXECUTED 116737
# 2011-12-30, BUY EXECUTED 116738
# 2011-12-30, Updating trailing stop for BUY position to 77.54 order number 116739
# 2011-12-30, Order Canceled: 116739
# 2011-12-30, Order Canceled: 116740
# 2011-12-30, Updating trailing stop for BUY position to 77.55 order number 116741
# 2011-12-30, Order Canceled: 116741
# 2011-12-30, SELL EXECUTED 116742
# 2011-12-30, SELL EXECUTED 116743
# ################################################################################
# Max loss hit. Resetting to starting balance: 5000
# ################################################################################
# 2011-12-30, Updating trailing stop for SELL position to 77.44 order number 116744
# 2011-12-30, Order Canceled: 116744
# 2011-12-30, Order Canceled: 116745
# 2011-12-30, Updating trailing stop for SELL position to 77.43 order number 116746
# 2011-12-30, Order Canceled: 116746
# 2011-12-30, Updating trailing stop for SELL position to 77.42 order number 116747
# 2011-12-30, Order Canceled: 116747
# 2011-12-30, Updating trailing stop for SELL position to 77.41 order number 116748
# 2011-12-30, Order Canceled: 116748
# 2011-12-30, Updating trailing stop for SELL position to 77.38 order number 116749
# 2011-12-30, Order Canceled: 116749
# 2011-12-30, Updating trailing stop for SELL position to 77.37 order number 116750
# 2011-12-30, Order Canceled: 116750
# 2011-12-30, Updating trailing stop for SELL position to 77.36 order number 116751
# 2011-12-30, Order Canceled: 116751
# 2011-12-30, Updating trailing stop for SELL position to 77.35 order number 116752
# 2011-12-30, Order Canceled: 116752
# 2011-12-30, Updating trailing stop for SELL position to 77.33 order number 116753
# 2011-12-30, Order Canceled: 116753
# 2011-12-30, Updating trailing stop for SELL position to 77.31 order number 116754
# 2011-12-30, Order Canceled: 116754
# 2011-12-30, Updating trailing stop for SELL position to 77.29 order number 116755
# 2011-12-30, Order Canceled: 116755
# 2011-12-30, Updating trailing stop for SELL position to 77.28 order number 116756
# 2011-12-30, Order Canceled: 116756
# 2011-12-30, Updating trailing stop for SELL position to 77.27 order number 116757
# 2011-12-30, Order Canceled: 116757
# 2011-12-30, Updating trailing stop for SELL position to 77.26 order number 116758
# 2011-12-30, Order Canceled: 116758
# 2011-12-30, Updating trailing stop for SELL position to 77.24 order number 116759
# 2011-12-30, Order Canceled: 116759
# 2011-12-30, Updating trailing stop for SELL position to 77.23 order number 116760
# 2011-12-30, Order Canceled: 116760
# 2011-12-30, Updating trailing stop for SELL position to 77.22 order number 116761
# 2011-12-30, Order Canceled: 116761
# 2011-12-30, Updating trailing stop for SELL position to 77.14 order number 116762
# 2011-12-30, Order Canceled: 116762
# 2011-12-30, Updating trailing stop for SELL position to 77.08 order number 116763
# 2011-12-30, Order Canceled: 116763
# 2011-12-30, Updating trailing stop for SELL position to 77.06 order number 116764
# 2011-12-30, Order Canceled: 116764
# 2011-12-30, Updating trailing stop for SELL position to 77.04 order number 116765
# 2011-12-30, Order Canceled: 116765
# 2011-12-30, Updating trailing stop for SELL position to 77.0 order number 116766
# 2011-12-30, Order Canceled: 116766
# 2011-12-30, BUY EXECUTED 116767
# Final Portfolio Value: 5046.90
